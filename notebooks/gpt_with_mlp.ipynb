# %%
# !pip uninstall nltk -y
# !pip install nltk
# !pip install --upgrade nltk

import nltk
nltk.download('punkt')
# Out:
# Found existing installation: nltk 3.8.1
# Uninstalling nltk-3.8.1:
#   Successfully uninstalled nltk-3.8.1
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2024.5.15)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.4)
# Installing collected packages: nltk
# Successfully installed nltk-3.8.1
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !pip install kaggle
# !pip install wandb
# !pip install python-dotenv
# Out:
# Requirement already satisfied: kaggle in /usr/local/lib/python3.10/dist-packages (1.6.14)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.10/dist-packages (from kaggle) (1.16.0)
# Requirement already satisfied: certifi>=2023.7.22 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2024.2.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.8.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from kaggle) (4.66.4)
# Requirement already satisfied: python-slugify in /usr/local/lib/python3.10/dist-packages (from kaggle) (8.0.4)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from kaggle) (2.0.7)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from kaggle) (6.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: text-unidecode>=1.3 in /usr/local/lib/python3.10/dist-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->kaggle) (3.7)
# Collecting wandb
#   Downloading wandb-0.17.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 18.2 MB/s eta 0:00:00
# Requirement already satisfied: click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting gitpython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 14.9 MB/s eta 0:00:00
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from wandb) (4.2.2)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from wandb) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (2.31.0)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-2.3.1-py2.py3-none-any.whl (289 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 289.0/289.0 kB 31.1 MB/s eta 0:00:00
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.2 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: smmap, setproctitle, sentry-sdk, docker-pycreds, gitdb, gitpython, wandb
# Successfully installed docker-pycreds-0.4.0 gitdb-4.0.11 gitpython-3.1.43 sentry-sdk-2.3.1 setproctitle-1.3.3 smmap-5.0.1 wandb-0.17.0
# Collecting python-dotenv
#   Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: python-dotenv
# Successfully installed python-dotenv-1.0.1

# %%
# !mkdir /.kaggle
# !mv /content/kaggle.json /.kaggle
# !mv /.kaggle /root/
# !chmod 600 ~/.kaggle/kaggle.json
# !ls ~/.kaggle/kaggle.json

# %%
# !kaggle datasets list -m

# %%
# !kaggle datasets download "nikitamalcev99/input-gpt2-kan"
# !unzip input-gpt2-kan.zip

# %%
import string
import re
import random
import torch
import torch.nn as nn
from torch.nn import functional as F

from torchvision.datasets import MNIST
from torch.utils.data import DataLoader
from torchvision import transforms
import torch.nn.init as init

from dotenv import load_dotenv, find_dotenv
import os
import wandb

__ENV_FILE = find_dotenv(f'{os.getenv("ENV", "var")}.env')
load_dotenv(__ENV_FILE)

os.environ["TORCH_USE_CUDA_DSA"] = "1"
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"

# %% [markdown]
# # CONFIG

# %%
# hyperparameters
BATCH_SIZE = 64 # B
BLOCK_SIZE = 14 # T
MAX_ITERS = 5_000
EVAL_INTERVAL = 500
LEARNING_RATE = 3e-4
DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
EVAL_ITERS = 200
N_EMBD = 128 + 64 # C
N_HEAD = 6 # D
N_LAYER = 6
DROPOUT = 0.2
# ------------

torch.manual_seed(42)

# %%
# hyperparameters
SHALLOW = False
if SHALLOW:
    BATCH_SIZE = 4 # B
    BLOCK_SIZE = 14 # T
    MAX_ITERS = 10_000 #100
    EVAL_INTERVAL = 1 #10
    LEARNING_RATE = 3e-4
    DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
    EVAL_ITERS = 1 #4
    N_EMBD = 16 # C
    N_HEAD = 6 # D = 384 // 6
    N_LAYER = 6
    DROPOUT = 0.2
    # ------------

    torch.manual_seed(42)

# %%
from huggingface_hub import login
login(token="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")
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
# wandb config

# WANDB_API_KEY = os.environ.get('WANDB_API_KEY')
WANDB_API_KEY="5b2ceb8edc2e4f40870207591750b6a38db675fc"
wandb.login(key=WANDB_API_KEY)

run = wandb.init(
    project="ADD_MLP_GPT2",
    config={
        "learning_rate": LEARNING_RATE,
        "epochs": MAX_ITERS,
        "entity": "",
        "group": "",
        "name": "",
    },
)
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.17.0
# Run data is saved locally in <code>/content/wandb/run-20240530_131810-nksd07ru</code>
# Syncing run <strong><a href='https://wandb.ai/pykan/ADD_MLP_GPT2/runs/nksd07ru' target="_blank">good-oath-12</a></strong> to <a href='https://wandb.ai/pykan/ADD_MLP_GPT2' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/pykan/ADD_MLP_GPT2' target="_blank">https://wandb.ai/pykan/ADD_MLP_GPT2</a>
#  View run at <a href='https://wandb.ai/pykan/ADD_MLP_GPT2/runs/nksd07ru' target="_blank">https://wandb.ai/pykan/ADD_MLP_GPT2/runs/nksd07ru</a>

# %% [markdown]
# # GET DATA

# %%
import random as rnd

with open("input.txt", "w") as istr:
    one_digit = 1_00_000
    two_digits = 1_00_000
    three_digits = 000_000 #100
    combo = 000_000 #100
    amount = [one_digit, two_digits, three_digits, combo]
    am_specific_range = [(0,10-1),(10,100-1),(100,1000-1),(-999,1000-1)]
    for am, am_range in zip(amount, am_specific_range):
        for _ in range(am):
            a = abs(rnd.randint(*am_range ))
            b = abs(rnd.randint(*am_range ))
            s = a+b
            sn = [c for c in str(s)]
            s = "".join(sn)

            template = "{:<3}+{:<3}={:<4} \n"
            s = template.format(a,b,s)
            s = s.replace(" ", ".")
            istr.write(s)

# %%
if os.environ.get('KAGGLE_KERNEL_RUN_TYPE',''):
    input_file_path = "../input/input-gpt2-kan/input.txt"
else:
    input_file_path = "input.txt"

with open(input_file_path, 'r', encoding='utf-8') as f:
    text = f.read()

# text = text[:14*100]

# %%
text[:14]
# Out:
# '1..+0..=1....\n'

# %% [markdown]
# # TOKENIZE

# %% [markdown]
# class Tokenizer:
#     def __init__(self, text_file_path) -> None:
#
#         self.stoi = {}
#         self.itos = {}
#
#         with open(text_file_path, 'r', encoding='utf-8') as f:
#             words = f.readlines()
#         for i in range(len(words)):
#             words[i] = words[i][:-1]
#         self.tok = nltk.tokenize.LegalitySyllableTokenizer(words, vowels='аеёиоуыэюяАЕЁИОУЫЭЮЯ')
#
#     def clean_line(self, text):
#         return re.sub(r"[^0-9а-яА-Я.,:-;!?+= ]", "", text)
#
#     def vocab_size(self):
#         return len(self.stoi)
#
#     def gimmi_tokens_from_file(self, filename):
#         tokens = []
#         with open(filename, 'r', encoding='utf-8') as file:
#             lines = file.readlines()
#         for line in lines:
#             line = self.clean_line(line)
#             worded_line = nltk.word_tokenize(text=line, language='russian')
#             final_tokens = []
#             for i in range(len(worded_line)):
#                 worded_line[i] = self.tok.tokenize(worded_line[i])
#                 if i == len(worded_line) - 1:
#                     worded_line[i].append('\n')
#                 elif worded_line[i][0] in string.punctuation or not(worded_line[i + 1][0] in string.punctuation):
#                      worded_line[i].append(' ')
#             final_tokens = [bebr for words in worded_line for bebr in words]
#             for token in final_tokens:
#                 tokens.append(token)
#         return tokens
#
#     def gimmi_tokens_from_text(self, text):
#         tokens = []
#         for line in text.split('\n'):
#             if line == '':
#                 tokens.append('\n')
#                 continue
#             line = self.clean_line(line)
#             worded_line = nltk.word_tokenize(text=line, language='russian')
#             final_tokens = []
#             for i in range(len(worded_line)):
#                 worded_line[i] = self.tok.tokenize(worded_line[i])
#                 if i == len(worded_line) - 1:
#                     worded_line[i].append('\n')
#                 elif worded_line[i][0] in string.punctuation or not(worded_line[i + 1][0] in string.punctuation):
#                      worded_line[i].append(' ')
#             final_tokens = [bebr for words in worded_line for bebr in words]
#             for token in final_tokens:
#                 tokens.append(token)
#         return tokens
#
#     def encode(self, text, is_file = False):
#         tokens = []
#         if is_file == True:
#             tokens = self.gimmi_tokens_from_file(text)
#         else:
#             tokens = self.gimmi_tokens_from_text(text)
#
#         for token in tokens:
#             if token not in self.stoi:
#                 self.stoi[token] = len(self.stoi)
#                 self.itos[len(self.stoi) - 1] = token
#
#         return [self.stoi.get(item) for item in tokens]
#
#     def decode(self, text):
#         return [self.itos.get(item) for item in text]

# %% [markdown]
# RuLangTokenizer = Tokenizer(text_file_path = input_file_path)
#
# encode = lambda s: RuLangTokenizer.encode(s)
# decode = lambda l: RuLangTokenizer.decode(l)

# %% [markdown]
# data = torch.tensor(encode(text), dtype=torch.long)
# VOCAB_SIZE = RuLangTokenizer.vocab_size()

# %%
with open(input_file_path, 'r', encoding='utf-8') as f:
    text = f.read()
    chars = sorted(list(set(text)))
    VOCAB_SIZE = len(chars)
    stoi = { ch:i for i,ch in enumerate(chars) }
    itos = { i:ch for i,ch in enumerate(chars) }

    encode = lambda s: [stoi[c] for c in s]
    decode = lambda l: ''.join([itos[i] for i in l])

dataset = {"train":[{"text":text}]}
data = []
for example in dataset["train"]:
    for el in encode(example["text"]):
        data.append(el)

data = torch.tensor(data, dtype=torch.long)

# %%
n = int(0.9*len(data))
train_data = data[:n]
val_data = data[n:]

# %%
assert len(data) > BLOCK_SIZE, f"not enough data in general for create block size. len data: {len(data)} < block size {BLOCK_SIZE}"
assert len(train_data) > BLOCK_SIZE, f"not enough data for create block size for train. len data: {len(train_data)} < block size {BLOCK_SIZE}"
assert len(val_data) > BLOCK_SIZE, f"not enough data for create block size for validation. len data: {len(val_data)} < block size {BLOCK_SIZE}"

# %%
def get_batch(split):
    data = train_data if split == 'train' else val_data
    ix = torch.randint(len(data) - BLOCK_SIZE, (BATCH_SIZE,))
    x = torch.stack([data[i:i+BLOCK_SIZE] for i in ix])
    y = torch.stack([data[i+1:i+BLOCK_SIZE+1] for i in ix])
    x, y = x.to(DEVICE), y.to(DEVICE)
    return x, y

# %%
def get_batch(split):
    data = train_data if split == 'train' else val_data

    valid_start_indexes = [x for x in range(0, len(data) - BLOCK_SIZE, BLOCK_SIZE)]

    ix = torch.tensor([random.choice(valid_start_indexes) for _ in range(BATCH_SIZE)]).view(BATCH_SIZE,)

    x = torch.stack(
        [data[ i : i + BLOCK_SIZE] for i in ix]
    )

    loss_mask = torch.where(
            torch.arange(BLOCK_SIZE) % BLOCK_SIZE < 7
        )[0]

    last_invalid_token_from_next = [BLOCK_SIZE -2, BLOCK_SIZE - 1]

    loss_mask = torch.concat((loss_mask, torch.tensor(last_invalid_token_from_next)))

    y = []

    for i in ix:
        y_data = torch.clone(data[i+1 : i+BLOCK_SIZE+1])
        y_data[loss_mask] = -100 # default ignore index = -100
        y.append(y_data)

    y = torch.stack(y)

    x, y = x.to(DEVICE), y.to(DEVICE)

    return x, y

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(EVAL_ITERS)
        for k in range(EVAL_ITERS):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %% [markdown]
# # MLP

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, num_heads, head_size):
        super().__init__()

        self.D = head_size
        self.H = num_heads
        self.register_buffer('tril', torch.tril(torch.ones(BLOCK_SIZE, BLOCK_SIZE)))
        self.key = nn.Linear(N_EMBD, head_size * num_heads, bias=False)
        self.query = nn.Linear(N_EMBD, head_size * num_heads, bias=False)
        self.value = nn.Linear(N_EMBD, head_size * num_heads, bias=False)
        self.proj = nn.Linear(head_size * num_heads, N_EMBD)

        self.dropout = nn.Dropout(DROPOUT)


    def forward(self, x):

        B,T,C = x.shape
        H = self.H
        D = self.D

        k = self.key(x).view(B, T, H, D)
        q = self.query(x).view(B, T, H, D)
        v = self.value(x).view(B, T, H, D)

        k = k.permute(0, 2, 3, 1)
        q = q.permute(0, 2, 1, 3)
        v = v.permute(0, 2, 1, 3)

        wei = q @ k * k.shape[-1]**-0.5

        wei = wei.masked_fill_(self.tril[:T,:T] == 0, float('-inf'))
        wei = F.softmax(wei, dim=-1)
        wei = self.dropout(wei)

        out = wei @ v
        out = out.permute(0, 2, 1, 3).reshape(B, T, -1)

        out = self.dropout(self.proj(out))
        return x

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.fc1 = nn.Linear(n_embd, 4 * n_embd)
        self.fc2 = nn.Linear(4 * n_embd, n_embd)

        self.net = nn.Sequential(
            self.fc1,
            nn.ReLU(),
            self.fc2,
            nn.Dropout(DROPOUT),
        )

        init.kaiming_uniform_(self.fc1.weight, nonlinearity='relu')
        init.kaiming_uniform_(self.fc2.weight, nonlinearity='relu')

    def forward(self, x):
        return self.net(x)
class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        x = x + self.sa(self.ln1(x)) # -> (B T C)
        x = x + self.ffwd(self.ln2(x)) # -> (B T C)

        return x
class GPTLanguageModel(nn.Module):

    def __init__(self):
        super().__init__()
        self.token_embedding_table = nn.Embedding(VOCAB_SIZE, N_EMBD)
        self.position_embedding_table = nn.Embedding(BLOCK_SIZE, N_EMBD)
        self.blocks = nn.Sequential(*[Block(N_EMBD, n_head=N_HEAD) for _ in range(N_LAYER)])
        self.ln_f = nn.LayerNorm(N_EMBD)
        self.lm_head = nn.Linear(N_EMBD, VOCAB_SIZE)

        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, idx, targets=None):
        B, T = idx.shape

        tok_emb = self.token_embedding_table(idx) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=DEVICE)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)

        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)

        return logits, loss

    def generate(self, idx, max_new_tokens):
        for _ in range(max_new_tokens):
            idx_cond = idx[:, -BLOCK_SIZE:]
            logits, loss = self(idx_cond)
            logits = logits[:, -1, :]
            probs = F.softmax(logits, dim=-1)
            idx_next = torch.multinomial(probs, num_samples=1)
            idx = torch.cat((idx, idx_next), dim=1)
        return idx

# %% [markdown]
# # KAN

# %% [markdown]
# import torch
# import torch.nn.functional as F
# import math
#
#
# class KANLinear(torch.nn.Module):
#     def __init__(
#         self,
#         in_features,
#         out_features,
#         grid_size=5,
#         spline_order=3,
#         scale_noise=0.1,
#         scale_base=1.0,
#         scale_spline=1.0,
#         enable_standalone_scale_spline=True,
#         base_activation=torch.nn.SiLU,
#         grid_eps=0.02,
#         grid_range=[-1, 1],
#     ):
#         super(KANLinear, self).__init__()
#         self.in_features = in_features
#         self.out_features = out_features
#         self.grid_size = grid_size
#         self.spline_order = spline_order
#
#         h = (grid_range[1] - grid_range[0]) / grid_size
#         grid = (
#             (
#                 torch.arange(-spline_order, grid_size + spline_order + 1) * h
#                 + grid_range[0]
#             )
#             .expand(in_features, -1)
#             .contiguous()
#         )
#         self.register_buffer("grid", grid)
#
#         self.base_weight = torch.nn.Parameter(torch.Tensor(out_features, in_features))
#         self.spline_weight = torch.nn.Parameter(
#             torch.Tensor(out_features, in_features, grid_size + spline_order)
#         )
#         if enable_standalone_scale_spline:
#             self.spline_scaler = torch.nn.Parameter(
#                 torch.Tensor(out_features, in_features)
#             )
#
#         self.scale_noise = scale_noise
#         self.scale_base = scale_base
#         self.scale_spline = scale_spline
#         self.enable_standalone_scale_spline = enable_standalone_scale_spline
#         self.base_activation = base_activation()
#         self.grid_eps = grid_eps
#
#         self.reset_parameters()
#
#     def reset_parameters(self):
#         torch.nn.init.kaiming_uniform_(self.base_weight, a=math.sqrt(5) * self.scale_base)
#         with torch.no_grad():
#             noise = (
#                 (
#                     torch.rand(self.grid_size + 1, self.in_features, self.out_features)
#                     - 1 / 2
#                 )
#                 * self.scale_noise
#                 / self.grid_size
#             )
#             self.spline_weight.data.copy_(
#                 (self.scale_spline if not self.enable_standalone_scale_spline else 1.0)
#                 * self.curve2coeff(
#                     self.grid.T[self.spline_order : -self.spline_order],
#                     noise,
#                 )
#             )
#             if self.enable_standalone_scale_spline:
#                 # torch.nn.init.constant_(self.spline_scaler, self.scale_spline)
#                 torch.nn.init.kaiming_uniform_(self.spline_scaler, a=math.sqrt(5) * self.scale_spline)
#
#     def b_splines(self, x: torch.Tensor):
#         """
#         Compute the B-spline bases for the given input tensor.
#
#         Args:
#             x (torch.Tensor): Input tensor of shape (batch_size, in_features).
#
#         Returns:
#             torch.Tensor: B-spline bases tensor of shape (batch_size, in_features, grid_size + spline_order).
#         """
#         assert x.dim() == 2 and x.size(1) == self.in_features
#
#         grid: torch.Tensor = (
#             self.grid
#         )  # (in_features, grid_size + 2 * spline_order + 1)
#         x = x.unsqueeze(-1)
#         bases = ((x >= grid[:, :-1]) & (x < grid[:, 1:])).to(x.dtype)
#         for k in range(1, self.spline_order + 1):
#             bases = (
#                 (x - grid[:, : -(k + 1)])
#                 / (grid[:, k:-1] - grid[:, : -(k + 1)])
#                 * bases[:, :, :-1]
#             ) + (
#                 (grid[:, k + 1 :] - x)
#                 / (grid[:, k + 1 :] - grid[:, 1:(-k)])
#                 * bases[:, :, 1:]
#             )
#
#         assert bases.size() == (
#             x.size(0),
#             self.in_features,
#             self.grid_size + self.spline_order,
#         )
#         return bases.contiguous()
#
#     def curve2coeff(self, x: torch.Tensor, y: torch.Tensor):
#         """
#         Compute the coefficients of the curve that interpolates the given points.
#
#         Args:
#             x (torch.Tensor): Input tensor of shape (batch_size, in_features).
#             y (torch.Tensor): Output tensor of shape (batch_size, in_features, out_features).
#
#         Returns:
#             torch.Tensor: Coefficients tensor of shape (out_features, in_features, grid_size + spline_order).
#         """
#         assert x.dim() == 2 and x.size(1) == self.in_features
#         assert y.size() == (x.size(0), self.in_features, self.out_features)
#
#         A = self.b_splines(x).transpose(
#             0, 1
#         )  # (in_features, batch_size, grid_size + spline_order)
#         B = y.transpose(0, 1)  # (in_features, batch_size, out_features)
#         solution = torch.linalg.lstsq(
#             A, B
#         ).solution  # (in_features, grid_size + spline_order, out_features)
#         result = solution.permute(
#             2, 0, 1
#         )  # (out_features, in_features, grid_size + spline_order)
#
#         assert result.size() == (
#             self.out_features,
#             self.in_features,
#             self.grid_size + self.spline_order,
#         )
#         return result.contiguous()
#
#     @property
#     def scaled_spline_weight(self):
#         return self.spline_weight * (
#             self.spline_scaler.unsqueeze(-1)
#             if self.enable_standalone_scale_spline
#             else 1.0
#         )
#
#     def forward(self, x: torch.Tensor):
#         assert x.size(-1) == self.in_features
#         original_shape = x.shape
#         x = x.view(-1, self.in_features)
#
#         base_output = F.linear(self.base_activation(x), self.base_weight)
#         spline_output = F.linear(
#             self.b_splines(x).view(x.size(0), -1),
#             self.scaled_spline_weight.view(self.out_features, -1),
#         )
#         output = base_output + spline_output
#
#         output = output.view(*original_shape[:-1], self.out_features)
#         return output
#
#     @torch.no_grad()
#     def update_grid(self, x: torch.Tensor, margin=0.01):
#         assert x.dim() == 2 and x.size(1) == self.in_features
#         batch = x.size(0)
#
#         splines = self.b_splines(x)  # (batch, in, coeff)
#         splines = splines.permute(1, 0, 2)  # (in, batch, coeff)
#         orig_coeff = self.scaled_spline_weight  # (out, in, coeff)
#         orig_coeff = orig_coeff.permute(1, 2, 0)  # (in, coeff, out)
#         unreduced_spline_output = torch.bmm(splines, orig_coeff)  # (in, batch, out)
#         unreduced_spline_output = unreduced_spline_output.permute(
#             1, 0, 2
#         )  # (batch, in, out)
#
#         # sort each channel individually to collect data distribution
#         x_sorted = torch.sort(x, dim=0)[0]
#         grid_adaptive = x_sorted[
#             torch.linspace(
#                 0, batch - 1, self.grid_size + 1, dtype=torch.int64, device=x.device
#             )
#         ]
#
#         uniform_step = (x_sorted[-1] - x_sorted[0] + 2 * margin) / self.grid_size
#         grid_uniform = (
#             torch.arange(
#                 self.grid_size + 1, dtype=torch.float32, device=x.device
#             ).unsqueeze(1)
#             * uniform_step
#             + x_sorted[0]
#             - margin
#         )
#
#         grid = self.grid_eps * grid_uniform + (1 - self.grid_eps) * grid_adaptive
#         grid = torch.concatenate(
#             [
#                 grid[:1]
#                 - uniform_step
#                 * torch.arange(self.spline_order, 0, -1, device=x.device).unsqueeze(1),
#                 grid,
#                 grid[-1:]
#                 + uniform_step
#                 * torch.arange(1, self.spline_order + 1, device=x.device).unsqueeze(1),
#             ],
#             dim=0,
#         )
#
#         self.grid.copy_(grid.T)
#         self.spline_weight.data.copy_(self.curve2coeff(x, unreduced_spline_output))
#
#     def regularization_loss(self, regularize_activation=1.0, regularize_entropy=1.0):
#         """
#         Compute the regularization loss.
#
#         This is a dumb simulation of the original L1 regularization as stated in the
#         paper, since the original one requires computing absolutes and entropy from the
#         expanded (batch, in_features, out_features) intermediate tensor, which is hidden
#         behind the F.linear function if we want an memory efficient implementation.
#
#         The L1 regularization is now computed as mean absolute value of the spline
#         weights. The authors implementation also includes this term in addition to the
#         sample-based regularization.
#         """
#         l1_fake = self.spline_weight.abs().mean(-1)
#         regularization_loss_activation = l1_fake.sum()
#         p = l1_fake / regularization_loss_activation
#         regularization_loss_entropy = -torch.sum(p * p.log())
#         return (
#             regularize_activation * regularization_loss_activation
#             + regularize_entropy * regularization_loss_entropy
#         )
#
#
# class KAN(torch.nn.Module):
#     def __init__(
#         self,
#         layers_hidden,
#         grid_size=5,
#         spline_order=3,
#         scale_noise=0.1,
#         scale_base=1.0,
#         scale_spline=1.0,
#         base_activation=torch.nn.SiLU,
#         grid_eps=0.02,
#         grid_range=[-1, 1],
#     ):
#         super(KAN, self).__init__()
#         self.grid_size = grid_size
#         self.spline_order = spline_order
#
#         self.layers = torch.nn.ModuleList()
#         for in_features, out_features in zip(layers_hidden, layers_hidden[1:]):
#             self.layers.append(
#                 KANLinear(
#                     in_features,
#                     out_features,
#                     grid_size=grid_size,
#                     spline_order=spline_order,
#                     scale_noise=scale_noise,
#                     scale_base=scale_base,
#                     scale_spline=scale_spline,
#                     base_activation=base_activation,
#                     grid_eps=grid_eps,
#                     grid_range=grid_range,
#                 )
#             )
#
#     def forward(self, x: torch.Tensor, update_grid=False):
#         for layer in self.layers:
#             if update_grid:
#                 layer.update_grid(x)
#             x = layer(x)
#         return x
#
#     def regularization_loss(self, regularize_activation=1.0, regularize_entropy=1.0):
#         return sum(
#             layer.regularization_loss(regularize_activation, regularize_entropy)
#             for layer in self.layers
#         )
# class MultiHeadAttention(nn.Module):
#     def __init__(self, num_heads, head_size):
#         super().__init__()
#
#         self.D = head_size
#         self.H = num_heads
#         self.register_buffer('tril', torch.tril(torch.ones(BLOCK_SIZE, BLOCK_SIZE)))
#         self.key = KAN([N_EMBD, head_size * num_heads])
#         self.query = KAN([N_EMBD, head_size * num_heads])
#         self.value = KAN([N_EMBD, head_size * num_heads])
#         self.proj = KAN([head_size * num_heads, N_EMBD])
#
#         self.dropout = nn.Dropout(DROPOUT)
#
#
#     def forward(self, x):
#
#         B,T,C = x.shape
#         H = self.H
#         D = self.D
#
#         k = self.key(x).view(B, T, H, D)
#         q = self.query(x).view(B, T, H, D)
#         v = self.value(x).view(B, T, H, D)
#
#         k = k.permute(0, 2, 3, 1)
#         q = q.permute(0, 2, 1, 3)
#         v = v.permute(0, 2, 1, 3)
#
#         wei = q @ k * k.shape[-1]**-0.5
#
#         wei = wei.masked_fill_(self.tril[:T,:T] == 0, float('-inf'))
#         wei = F.softmax(wei, dim=-1)
#         wei = self.dropout(wei)
#
#         out = wei @ v
#         out = out.permute(0, 2, 1, 3).reshape(B, T, -1)
#
#         out = self.dropout(self.proj(out))
#         return x
#
# class FeedFoward(nn.Module):
#     """ a simple linear layer followed by a non-linearity """
#
#     def __init__(self, n_embd):
#         super().__init__()
#         self.net = nn.Sequential(
#             KAN([n_embd, n_embd]),
#             nn.Dropout(DROPOUT),
#         )
#     def forward(self, x):
#         return self.net(x)
#
# class Block(nn.Module):
#     """ Transformer block: communication followed by computation """
#
#     def __init__(self, n_embd, n_head):
#         super().__init__()
#         head_size = n_embd // n_head
#         self.sa = MultiHeadAttention(n_head, head_size)
#         self.ffwd = FeedFoward(n_embd)
#         self.ln1 = nn.LayerNorm(n_embd)
#         self.ln2 = nn.LayerNorm(n_embd)
#
#     def forward(self, x):
#         x = x + self.sa(self.ln1(x)) # -> (B T C)
#         x = x + self.ffwd(self.ln2(x)) # -> (B T C)
#
#         return x
# class GPTLanguageModel(nn.Module):
#
#     def __init__(self):
#         super().__init__()
#         self.token_embedding_table = nn.Embedding(VOCAB_SIZE, N_EMBD)
#         self.position_embedding_table = nn.Embedding(BLOCK_SIZE, N_EMBD)
#         self.blocks = nn.Sequential(*[Block(N_EMBD, n_head=N_HEAD) for _ in range(N_LAYER)])
#         self.ln_f = nn.LayerNorm(N_EMBD)
#
#         self.lm_head = KAN([N_EMBD, VOCAB_SIZE])
#
#         self.apply(self._init_weights)
#
#     def _init_weights(self, module):
#         if isinstance(module, nn.Linear):
#             torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
#             if module.bias is not None:
#                 torch.nn.init.zeros_(module.bias)
#         elif isinstance(module, nn.Embedding):
#             torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
#
#     def forward(self, idx, targets=None):
#         B, T = idx.shape
#
#         tok_emb = self.token_embedding_table(idx) # (B,T,C)
#         pos_emb = self.position_embedding_table(torch.arange(T, device=DEVICE)) # (T,C)
#         x = tok_emb + pos_emb # (B,T,C)
#         x = self.blocks(x) # (B,T,C)
#         x = self.ln_f(x) # (B,T,C)
#         logits = self.lm_head(x) # (B,T,vocab_size)
#
#         if targets is None:
#             loss = None
#         else:
#             B, T, C = logits.shape
#             logits = logits.view(B*T, C)
#             targets = targets.view(B*T)
#             loss = F.cross_entropy(logits, targets)
#
#         return logits, loss
#
#     def generate(self, idx, max_new_tokens):
#         for _ in range(max_new_tokens):
#             idx_cond = idx[:, -BLOCK_SIZE:]
#             logits, loss = self(idx_cond)
#             logits = logits[:, -1, :]
#             probs = F.softmax(logits, dim=-1)
#             idx_next = torch.multinomial(probs, num_samples=1)
#             idx = torch.cat((idx, idx_next), dim=1)
#         return idx

# %% [markdown]
# # Train

# %%
from transformers import PreTrainedModel, PretrainedConfig
from transformers import AutoModel, AutoConfig

class GPTConfig(PretrainedConfig):
    def __init__(self,
                 **kwargs):
        super().__init__(**kwargs)

class GPTModel(PreTrainedModel):
    config_class: GPTConfig = GPTConfig
    def __init__(self, config):
        super().__init__(config)
        self.config = config
        self.model = GPTLanguageModel()
    def generate(self, idx, max_new_tokens):
        return self.model.generate(idx, max_new_tokens)
    def forward(self, idx, targets=None):
        return self.model(idx, targets)

# %%
config = GPTConfig()
model = GPTModel(config)

m = model.to(DEVICE)
print(sum(p.numel() for p in m.parameters())/1e6, 'M parameters')
# Out:
# 2.67419 M parameters

# %%
from tqdm import tqdm
wandb.watch(model, log="all")
wandb.log({'M_parameters' : sum(p.numel() for p in m.parameters())/1e6})
optimizer = torch.optim.AdamW(model.parameters(), lr=LEARNING_RATE)

for iter in tqdm(range(MAX_ITERS)):

    if iter % EVAL_INTERVAL == 0 or iter == MAX_ITERS - 1:
        losses = estimate_loss()
        wandb.log({"validation loss": losses})
        print(f"step {iter}: train loss {losses['train']:.4f}, val loss {losses['val']:.4f}")

    xb, yb = get_batch('train')

    logits, loss = model(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
    wandb.log({"train loss": loss})

wandb.finish()
# Out:
#   0%|          | 3/5000 [00:08<3:05:03,  2.22s/it]
# step 0: train loss 2.6609, val loss 2.6610
#  10%|█         | 503/5000 [00:35<46:55,  1.60it/s]
# step 500: train loss 0.9209, val loss 1.2632
#  20%|██        | 1002/5000 [01:04<54:38,  1.22it/s]
# step 1000: train loss 0.9126, val loss 1.2280
#  30%|███       | 1502/5000 [01:35<41:59,  1.39it/s]
# step 1500: train loss 0.9137, val loss 1.2370
#  40%|████      | 2003/5000 [02:06<39:58,  1.25it/s]
# step 2000: train loss 0.9173, val loss 1.2147
#  50%|█████     | 2502/5000 [02:36<46:40,  1.12s/it]
# step 2500: train loss 0.9208, val loss 1.2474
#  60%|██████    | 3003/5000 [03:08<19:06,  1.74it/s]
# step 3000: train loss 0.9213, val loss 1.2572
#  70%|███████   | 3502/5000 [03:39<20:17,  1.23it/s]
# step 3500: train loss 0.9146, val loss 1.2244
#  80%|████████  | 4002/5000 [04:10<17:49,  1.07s/it]
# step 4000: train loss 0.9127, val loss 1.2320
#  90%|█████████ | 4501/5000 [04:40<06:10,  1.35it/s]
# step 4500: train loss 0.9133, val loss 1.2393
# 100%|██████████| 5000/5000 [05:11<00:00, 16.06it/s]
# step 4999: train loss 0.9186, val loss 1.2397
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>M_parameters</td><td>▁</td></tr><tr><td>train loss</td><td>▆▅▄▅▅▄▅▃▆▁▇▅▆█▆▅▅▄▃▃▄▅▃▄▂▅▇▄▆▆▇▅▇▅▃▄▅▄▆▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>M_parameters</td><td>2.67419</td></tr><tr><td>train loss</td><td>0.90039</td></tr></table><br/></div></div>
#  View run <strong style="color:#cdcd00">good-oath-12</strong> at: <a href='https://wandb.ai/pykan/ADD_MLP_GPT2/runs/nksd07ru' target="_blank">https://wandb.ai/pykan/ADD_MLP_GPT2/runs/nksd07ru</a><br/> View project at: <a href='https://wandb.ai/pykan/ADD_MLP_GPT2' target="_blank">https://wandb.ai/pykan/ADD_MLP_GPT2</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240530_131810-nksd07ru/logs</code>

# %%
# m.save_pretrained('gpt2andmlp',push_to_hub=True)
torch.save(m.state_dict(), "gpt2andmlp.state")

# %%
# from transformers import AutoModel
# model = AutoModel.from_pretrained("Malecc/gpt2andmlp")

# %%
sample = encode("2..+2..=")
context = torch.tensor(sample ,dtype=torch.long, device=DEVICE).view(-1,len(sample))
print("".join(decode(m.generate(context, max_new_tokens=4)[0].tolist())))
# Out:
# 2..+2..=6...

# %% [markdown]
# # METRICS

# %%
import random as rnd

with open("add.txt", "w") as istr:
    one_digit = 100
    two_digits = 100
    three_digits = 100
    combo = 100
    amount = [one_digit, two_digits, three_digits, combo]
    am_specific_range = [(0,10-1),(10,100-1),(100,1000-1),(-999,1000-1)]
    for am, am_range in zip(amount, am_specific_range):
        for _ in range(am):
            a = abs(rnd.randint(*am_range ))
            b = abs(rnd.randint(*am_range ))
            s = a+b
            sn = [c for c in str(s)]
            s = "".join(sn)

            template = "{:<3}+{:<3}={:<4} \n"
            s = template.format(a,b,s)
            s = s.replace(" ", ".")
            istr.write(s)

# %%
pos = 0
all_res = 0
# i = 5
with open("add.txt", "r") as f:
    for line in f.readlines():
        sample = encode(line[:8])
        target = line[8:-2] # убать "|" и "\n"
        context = torch.tensor(sample ,dtype=torch.long, device=DEVICE).view(-1,len(sample))
        check = False

        print("INPUT : ", line[:8])

        for step in range(4):
            max_new_tokens = 4
            pred_to_test =decode(
                m.generate(context, max_new_tokens = max_new_tokens)[0].tolist()
            )
            print("ATTEMPT: ", step)
            print("TARGET : ", target)
            print("PRED : ", pred_to_test[8:])

            if set(target).issubset(set(pred_to_test)):
                check = True
                print(f"POS: {set(target)} and {set(pred_to_test)}")

        all_res += 1
        if check:
            pos += 1

        print("*"*20)
        # i-=1
        # if i <= 0:
        #     break


print(f"Accuracy: {pos/all_res}")
# Out:
# Streaming output truncated to the last 5000 lines.
# TARGET :  10..
# PRED :  8...
# ********************
# INPUT :  3..+7..=
# ATTEMPT:  0
# TARGET :  10..
# PRED :  113.
# ATTEMPT:  1
# TARGET :  10..
# PRED :  8...
# ATTEMPT:  2
# TARGET :  10..
# PRED :  8...
# ATTEMPT:  3
# TARGET :  10..
# PRED :  2...
# ********************
# INPUT :  0..+9..=
# ATTEMPT:  0
# TARGET :  9...
# PRED :  116.
# POS: {'9', '.'} and {'6', '9', '1', '.', '+', '0', '='}
# ATTEMPT:  1
# TARGET :  9...
# PRED :  94..
# POS: {'9', '.'} and {'9', '.', '+', '4', '0', '='}
# ATTEMPT:  2
# TARGET :  9...
# PRED :  13..
# POS: {'9', '.'} and {'9', '1', '.', '+', '3', '0', '='}
# ATTEMPT:  3
# TARGET :  9...
# PRED :  19..
# POS: {'9', '.'} and {'9', '1', '.', '+', '0', '='}
# ********************
# INPUT :  4..+1..=
# ATTEMPT:  0
# TARGET :  5...
# PRED :  6...
# ATTEMPT:  1
# TARGET :  5...
# PRED :  9...
# ATTEMPT:  2
# TARGET :  5...
# PRED :  15..
# POS: {'5', '.'} and {'1', '.', '+', '5', '4', '='}
# ATTEMPT:  3
# TARGET :  5...
# PRED :  105.
# POS: {'5', '.'} and {'1', '.', '+', '5', '4', '0', '='}
# ********************
# INPUT :  6..+9..=
# ATTEMPT:  0
# TARGET :  15..
# PRED :  11..
# ATTEMPT:  1
# TARGET :  15..
# PRED :  72..
# ATTEMPT:  2
# TARGET :  15..
# PRED :  7...
# ATTEMPT:  3
# TARGET :  15..
# PRED :  98..
# ********************
# INPUT :  3..+3..=
# ATTEMPT:  0
# TARGET :  6...
# PRED :  165.
# POS: {'6', '.'} and {'6', '1', '.', '+', '5', '3', '='}
# ATTEMPT:  1
# TARGET :  6...
# PRED :  9...
# ATTEMPT:  2
# TARGET :  6...
# PRED :  13..
# ATTEMPT:  3
# TARGET :  6...
# PRED :  12..
# ********************
# INPUT :  3..+5..=
# ATTEMPT:  0
# TARGET :  8...
# PRED :  11..
# ATTEMPT:  1
# TARGET :  8...
# PRED :  90..
# ATTEMPT:  2
# TARGET :  8...
# PRED :  12..
# ATTEMPT:  3
# TARGET :  8...
# PRED :  119.
# ********************
# INPUT :  4..+0..=
# ATTEMPT:  0
# TARGET :  4...
# PRED :  88..
# POS: {'4', '.'} and {'.', '+', '4', '0', '8', '='}
# ATTEMPT:  1
# TARGET :  4...
# PRED :  68..
# POS: {'4', '.'} and {'6', '.', '+', '4', '0', '8', '='}
# ATTEMPT:  2
# TARGET :  4...
# PRED :  101.
# POS: {'4', '.'} and {'1', '.', '+', '4', '0', '='}
# ATTEMPT:  3
# TARGET :  4...
# PRED :  133.
# POS: {'4', '.'} and {'1', '.', '+', '3', '4', '0', '='}
# ********************
# INPUT :  6..+5..=
# ATTEMPT:  0
# TARGET :  11..
# PRED :  5...
# ATTEMPT:  1
# TARGET :  11..
# PRED :  100.
# POS: {'1', '.'} and {'6', '1', '.', '+', '5', '0', '='}
# ATTEMPT:  2
# TARGET :  11..
# PRED :  4...
# ATTEMPT:  3
# TARGET :  11..
# PRED :  68..
# ********************
# INPUT :  6..+2..=
# ATTEMPT:  0
# TARGET :  8...
# PRED :  8...
# POS: {'.', '8'} and {'6', '.', '+', '8', '2', '='}
# ATTEMPT:  1
# TARGET :  8...
# PRED :  76..
# ATTEMPT:  2
# TARGET :  8...
# PRED :  4...
# ATTEMPT:  3
# TARGET :  8...
# PRED :  736.
# ********************
# INPUT :  2..+6..=
# ATTEMPT:  0
# TARGET :  8...
# PRED :  14..
# ATTEMPT:  1
# TARGET :  8...
# PRED :  7...
# ATTEMPT:  2
# TARGET :  8...
# PRED :  104.
# ATTEMPT:  3
# TARGET :  8...
# PRED :  2...
# ********************
# INPUT :  5..+7..=
# ATTEMPT:  0
# TARGET :  12..
# PRED :  9...
# ATTEMPT:  1
# TARGET :  12..
# PRED :  12..
# POS: {'2', '1', '.'} and {'7', '1', '.', '+', '5', '2', '='}
# ATTEMPT:  2
# TARGET :  12..
# PRED :  1...
# ATTEMPT:  3
# TARGET :  12..
# PRED :  182.
# POS: {'2', '1', '.'} and {'7', '1', '.', '+', '5', '8', '2', '='}
# ********************
# INPUT :  2..+9..=
# ATTEMPT:  0
# TARGET :  11..
# PRED :  9...
# ATTEMPT:  1
# TARGET :  11..
# PRED :  10..
# POS: {'1', '.'} and {'9', '1', '.', '+', '0', '2', '='}
# ATTEMPT:  2
# TARGET :  11..
# PRED :  9...
# ATTEMPT:  3
# TARGET :  11..
# PRED :  10..
# POS: {'1', '.'} and {'9', '1', '.', '+', '0', '2', '='}
# ********************
# INPUT :  4..+1..=
# ATTEMPT:  0
# TARGET :  5...
# PRED :  99..
# ATTEMPT:  1
# TARGET :  5...
# PRED :  78..
# ATTEMPT:  2
# TARGET :  5...
# PRED :  13..
# ATTEMPT:  3
# TARGET :  5...
# PRED :  13..
# ********************
# INPUT :  3..+0..=
# ATTEMPT:  0
# TARGET :  3...
# PRED :  115.
# POS: {'.', '3'} and {'1', '.', '+', '5', '3', '0', '='}
# ATTEMPT:  1
# TARGET :  3...
# PRED :  89..
# POS: {'.', '3'} and {'9', '.', '+', '3', '0', '8', '='}
# ATTEMPT:  2
# TARGET :  3...
# PRED :  8...
# POS: {'.', '3'} and {'.', '+', '3', '0', '8', '='}
# ATTEMPT:  3
# TARGET :  3...
# PRED :  36..
# POS: {'.', '3'} and {'6', '.', '+', '3', '0', '='}
# ********************
# INPUT :  3..+6..=
# ATTEMPT:  0
# TARGET :  9...
# PRED :  13..
# ATTEMPT:  1
# TARGET :  9...
# PRED :  347.
# ATTEMPT:  2
# TARGET :  9...
# PRED :  11..
# ATTEMPT:  3
# TARGET :  9...
# PRED :  9...
# POS: {'9', '.'} and {'6', '9', '.', '+', '3', '='}
# ********************
# INPUT :  3..+0..=
# ATTEMPT:  0
# TARGET :  3...
# PRED :  10..
# POS: {'.', '3'} and {'1', '.', '+', '3', '0', '='}
# ATTEMPT:  1
# TARGET :  3...
# PRED :  504.
# POS: {'.', '3'} and {'.', '+', '5', '3', '4', '0', '='}
# ATTEMPT:  2
# TARGET :  3...
# PRED :  9...
# POS: {'.', '3'} and {'9', '.', '+', '3', '0', '='}
# ATTEMPT:  3
# TARGET :  3...
# PRED :  82..
# POS: {'.', '3'} and {'.', '+', '3', '0', '8', '2', '='}
# ********************
# INPUT :  3..+9..=
# ATTEMPT:  0
# TARGET :  12..
# PRED :  132.
# POS: {'2', '1', '.'} and {'9', '1', '.', '+', '3', '2', '='}
# ATTEMPT:  1
# TARGET :  12..
# PRED :  71..
# ATTEMPT:  2
# TARGET :  12..
# PRED :  71..
# ATTEMPT:  3
# TARGET :  12..
# PRED :  12..
# POS: {'2', '1', '.'} and {'9', '1', '.', '+', '3', '2', '='}
# ********************
# INPUT :  8..+0..=
# ATTEMPT:  0
# TARGET :  8...
# PRED :  57..
# POS: {'.', '8'} and {'7', '.', '+', '5', '0', '8', '='}
# ATTEMPT:  1
# TARGET :  8...
# PRED :  38..
# POS: {'.', '8'} and {'.', '+', '3', '0', '8', '='}
# ATTEMPT:  2
# TARGET :  8...
# PRED :  150.
# POS: {'.', '8'} and {'1', '.', '+', '5', '0', '8', '='}
# ATTEMPT:  3
# TARGET :  8...
# PRED :  11..
# POS: {'.', '8'} and {'1', '.', '+', '0', '8', '='}
# ********************
# INPUT :  1..+2..=
# ATTEMPT:  0
# TARGET :  3...
# PRED :  932.
# POS: {'.', '3'} and {'1', '9', '.', '+', '3', '2', '='}
# ATTEMPT:  1
# TARGET :  3...
# PRED :  133.
# POS: {'.', '3'} and {'1', '.', '+', '3', '2', '='}
# ATTEMPT:  2
# TARGET :  3...
# PRED :  12..
# ATTEMPT:  3
# TARGET :  3...
# PRED :  104.
# ********************
# INPUT :  7..+4..=
# ATTEMPT:  0
# TARGET :  11..
# PRED :  104.
# POS: {'1', '.'} and {'7', '1', '.', '+', '4', '0', '='}
# ATTEMPT:  1
# TARGET :  11..
# PRED :  7...
# ATTEMPT:  2
# TARGET :  11..
# PRED :  10..
# POS: {'1', '.'} and {'7', '1', '.', '+', '4', '0', '='}
# ATTEMPT:  3
# TARGET :  11..
# PRED :  105.
# POS: {'1', '.'} and {'7', '1', '.', '+', '5', '4', '0', '='}
# ********************
# INPUT :  6..+3..=
# ATTEMPT:  0
# TARGET :  9...
# PRED :  9...
# POS: {'9', '.'} and {'6', '9', '.', '+', '3', '='}
# ATTEMPT:  1
# TARGET :  9...
# PRED :  146.
# ATTEMPT:  2
# TARGET :  9...
# PRED :  7...
# ATTEMPT:  3
# TARGET :  9...
# PRED :  5...
# ********************
# INPUT :  1..+2..=
# ATTEMPT:  0
# TARGET :  3...
# PRED :  10..
# ATTEMPT:  1
# TARGET :  3...
# PRED :  8...
# ATTEMPT:  2
# TARGET :  3...
# PRED :  8...
# ATTEMPT:  3
# TARGET :  3...
# PRED :  9...
# ********************
# INPUT :  6..+3..=
# ATTEMPT:  0
# TARGET :  9...
# PRED :  79..
# POS: {'9', '.'} and {'6', '7', '9', '.', '+', '3', '='}
# ATTEMPT:  1
# TARGET :  9...
# PRED :  10..
# ATTEMPT:  2
# TARGET :  9...
# PRED :  11..
# ATTEMPT:  3
# TARGET :  9...
# PRED :  147.
# ********************
# INPUT :  3..+2..=
# ATTEMPT:  0
# TARGET :  5...
# PRED :  17..
# ATTEMPT:  1
# TARGET :  5...
# PRED :  69..
# ATTEMPT:  2
# TARGET :  5...
# PRED :  8...
# ATTEMPT:  3
# TARGET :  5...
# PRED :  112.
# ********************
# INPUT :  8..+0..=
# ATTEMPT:  0
# TARGET :  8...
# PRED :  88..
# POS: {'.', '8'} and {'.', '+', '0', '8', '='}
# ATTEMPT:  1
# TARGET :  8...
# PRED :  11..
# POS: {'.', '8'} and {'1', '.', '+', '0', '8', '='}
# ATTEMPT:  2
# TARGET :  8...
# PRED :  13..
# POS: {'.', '8'} and {'1', '.', '+', '3', '0', '8', '='}
# ATTEMPT:  3
# TARGET :  8...
# PRED :  3...
# POS: {'.', '8'} and {'.', '+', '3', '0', '8', '='}
# ********************
# INPUT :  4..+9..=
# ATTEMPT:  0
# TARGET :  13..
# PRED :  2...
# ATTEMPT:  1
# TARGET :  13..
# PRED :  15..
# ATTEMPT:  2
# TARGET :  13..
# PRED :  18..
# ATTEMPT:  3
# TARGET :  13..
# PRED :  832.
# ********************
# INPUT :  0..+6..=
# ATTEMPT:  0
# TARGET :  6...
# PRED :  127.
# POS: {'6', '.'} and {'6', '7', '1', '.', '+', '0', '2', '='}
# ATTEMPT:  1
# TARGET :  6...
# PRED :  13..
# POS: {'6', '.'} and {'6', '1', '.', '+', '3', '0', '='}
# ATTEMPT:  2
# TARGET :  6...
# PRED :  12..
# POS: {'6', '.'} and {'6', '1', '.', '+', '0', '2', '='}
# ATTEMPT:  3
# TARGET :  6...
# PRED :  775.
# POS: {'6', '.'} and {'6', '7', '.', '+', '5', '0', '='}
# ********************
# INPUT :  5..+2..=
# ATTEMPT:  0
# TARGET :  7...
# PRED :  8...
# ATTEMPT:  1
# TARGET :  7...
# PRED :  95..
# ATTEMPT:  2
# TARGET :  7...
# PRED :  5...
# ATTEMPT:  3
# TARGET :  7...
# PRED :  10..
# ********************
# INPUT :  5..+6..=
# ATTEMPT:  0
# TARGET :  11..
# PRED :  4...
# ATTEMPT:  1
# TARGET :  11..
# PRED :  9...
# ATTEMPT:  2
# TARGET :  11..
# PRED :  72..
# ATTEMPT:  3
# TARGET :  11..
# PRED :  9...
# ********************
# INPUT :  6..+6..=
# ATTEMPT:  0
# TARGET :  12..
# PRED :  109.
# ATTEMPT:  1
# TARGET :  12..
# PRED :  6...
# ATTEMPT:  2
# TARGET :  12..
# PRED :  8...
# ATTEMPT:  3
# TARGET :  12..
# PRED :  11..
# ********************
# INPUT :  3..+9..=
# ATTEMPT:  0
# TARGET :  12..
# PRED :  11..
# ATTEMPT:  1
# TARGET :  12..
# PRED :  4...
# ATTEMPT:  2
# TARGET :  12..
# PRED :  1...
# ATTEMPT:  3
# TARGET :  12..
# PRED :  104.
# ********************
# INPUT :  5..+7..=
# ATTEMPT:  0
# TARGET :  12..
# PRED :  16..
# ATTEMPT:  1
# TARGET :  12..
# PRED :  14..
# ATTEMPT:  2
# TARGET :  12..
# PRED :  982.
# ATTEMPT:  3
# TARGET :  12..
# PRED :  13..
# ********************
# INPUT :  7..+9..=
# ATTEMPT:  0
# TARGET :  16..
# PRED :  13..
# ATTEMPT:  1
# TARGET :  16..
# PRED :  9...
# ATTEMPT:  2
# TARGET :  16..
# PRED :  11..
# ATTEMPT:  3
# TARGET :  16..
# PRED :  89..
# ********************
# INPUT :  7..+3..=
# ATTEMPT:  0
# TARGET :  10..
# PRED :  16..
# ATTEMPT:  1
# TARGET :  10..
# PRED :  50..
# ATTEMPT:  2
# TARGET :  10..
# PRED :  8...
# ATTEMPT:  3
# TARGET :  10..
# PRED :  5...
# ********************
# INPUT :  9..+8..=
# ATTEMPT:  0
# TARGET :  17..
# PRED :  8...
# ATTEMPT:  1
# TARGET :  17..
# PRED :  92..
# ATTEMPT:  2
# TARGET :  17..
# PRED :  9...
# ATTEMPT:  3
# TARGET :  17..
# PRED :  3...
# ********************
# INPUT :  4..+3..=
# ATTEMPT:  0
# TARGET :  7...
# PRED :  626.
# ATTEMPT:  1
# TARGET :  7...
# PRED :  9...
# ATTEMPT:  2
# TARGET :  7...
# PRED :  11..
# ATTEMPT:  3
# TARGET :  7...
# PRED :  143.
# ********************
# INPUT :  2..+9..=
# ATTEMPT:  0
# TARGET :  11..
# PRED :  75..
# ATTEMPT:  1
# TARGET :  11..
# PRED :  164.
# POS: {'1', '.'} and {'6', '9', '1', '.', '+', '4', '2', '='}
# ATTEMPT:  2
# TARGET :  11..
# PRED :  12..
# POS: {'1', '.'} and {'9', '1', '.', '+', '2', '='}
# ATTEMPT:  3
# TARGET :  11..
# PRED :  9...
# ********************
# INPUT :  5..+0..=
# ATTEMPT:  0
# TARGET :  5...
# PRED :  648.
# POS: {'5', '.'} and {'6', '.', '+', '5', '4', '0', '8', '='}
# ATTEMPT:  1
# TARGET :  5...
# PRED :  130.
# POS: {'5', '.'} and {'1', '.', '+', '5', '3', '0', '='}
# ATTEMPT:  2
# TARGET :  5...
# PRED :  2...
# POS: {'5', '.'} and {'.', '+', '5', '0', '2', '='}
# ATTEMPT:  3
# TARGET :  5...
# PRED :  6...
# POS: {'5', '.'} and {'6', '.', '+', '5', '0', '='}
# ********************
# INPUT :  5..+1..=
# ATTEMPT:  0
# TARGET :  6...
# PRED :  3...
# ATTEMPT:  1
# TARGET :  6...
# PRED :  7...
# ATTEMPT:  2
# TARGET :  6...
# PRED :  88..
# ATTEMPT:  3
# TARGET :  6...
# PRED :  65..
# POS: {'6', '.'} and {'6', '1', '.', '+', '5', '='}
# ********************
# INPUT :  7..+9..=
# ATTEMPT:  0
# TARGET :  16..
# PRED :  11..
# ATTEMPT:  1
# TARGET :  16..
# PRED :  94..
# ATTEMPT:  2
# TARGET :  16..
# PRED :  626.
# ATTEMPT:  3
# TARGET :  16..
# PRED :  143.
# ********************
# INPUT :  81.+86.=
# ATTEMPT:  0
# TARGET :  167.
# PRED :  135.
# ATTEMPT:  1
# TARGET :  167.
# PRED :  144.
# ATTEMPT:  2
# TARGET :  167.
# PRED :  14..
# ATTEMPT:  3
# TARGET :  167.
# PRED :  111.
# ********************
# INPUT :  31.+23.=
# ATTEMPT:  0
# TARGET :  54..
# PRED :  16..
# ATTEMPT:  1
# TARGET :  54..
# PRED :  14..
# ATTEMPT:  2
# TARGET :  54..
# PRED :  10..
# ATTEMPT:  3
# TARGET :  54..
# PRED :  12..
# ********************
# INPUT :  39.+29.=
# ATTEMPT:  0
# TARGET :  68..
# PRED :  9...
# ATTEMPT:  1
# TARGET :  68..
# PRED :  14..
# ATTEMPT:  2
# TARGET :  68..
# PRED :  100.
# ATTEMPT:  3
# TARGET :  68..
# PRED :  11..
# ********************
# INPUT :  11.+50.=
# ATTEMPT:  0
# TARGET :  61..
# PRED :  2...
# ATTEMPT:  1
# TARGET :  61..
# PRED :  8...
# ATTEMPT:  2
# TARGET :  61..
# PRED :  139.
# ATTEMPT:  3
# TARGET :  61..
# PRED :  11..
# ********************
# INPUT :  80.+68.=
# ATTEMPT:  0
# TARGET :  148.
# PRED :  12..
# ATTEMPT:  1
# TARGET :  148.
# PRED :  10..
# ATTEMPT:  2
# TARGET :  148.
# PRED :  14..
# POS: {'4', '.', '1', '8'} and {'6', '1', '.', '+', '4', '0', '8', '='}
# ATTEMPT:  3
# TARGET :  148.
# PRED :  3...
# ********************
# INPUT :  66.+79.=
# ATTEMPT:  0
# TARGET :  145.
# PRED :  128.
# ATTEMPT:  1
# TARGET :  145.
# PRED :  880.
# ATTEMPT:  2
# TARGET :  145.
# PRED :  12..
# ATTEMPT:  3
# TARGET :  145.
# PRED :  2...
# ********************
# INPUT :  18.+86.=
# ATTEMPT:  0
# TARGET :  104.
# PRED :  138.
# ATTEMPT:  1
# TARGET :  104.
# PRED :  9...
# ATTEMPT:  2
# TARGET :  104.
# PRED :  9...
# ATTEMPT:  3
# TARGET :  104.
# PRED :  94..
# ********************
# INPUT :  86.+51.=
# ATTEMPT:  0
# TARGET :  137.
# PRED :  9...
# ATTEMPT:  1
# TARGET :  137.
# PRED :  415.
# ATTEMPT:  2
# TARGET :  137.
# PRED :  12..
# ATTEMPT:  3
# TARGET :  137.
# PRED :  2...
# ********************
# INPUT :  32.+59.=
# ATTEMPT:  0
# TARGET :  91..
# PRED :  105.
# POS: {'1', '9', '.'} and {'9', '1', '.', '+', '5', '3', '0', '2', '='}
# ATTEMPT:  1
# TARGET :  91..
# PRED :  136.
# POS: {'1', '9', '.'} and {'6', '9', '1', '.', '+', '5', '3', '2', '='}
# ATTEMPT:  2
# TARGET :  91..
# PRED :  1...
# POS: {'1', '9', '.'} and {'9', '1', '.', '+', '5', '3', '2', '='}
# ATTEMPT:  3
# TARGET :  91..
# PRED :  118.
# POS: {'1', '9', '.'} and {'9', '1', '.', '+', '5', '3', '8', '2', '='}
# ********************
# INPUT :  12.+17.=
# ATTEMPT:  0
# TARGET :  29..
# PRED :  2...
# ATTEMPT:  1
# TARGET :  29..
# PRED :  13..
# ATTEMPT:  2
# TARGET :  29..
# PRED :  11..
# ATTEMPT:  3
# TARGET :  29..
# PRED :  139.
# POS: {'9', '2', '.'} and {'7', '1', '9', '.', '+', '3', '2', '='}
# ********************
# INPUT :  56.+82.=
# ATTEMPT:  0
# TARGET :  138.
# PRED :  90..
# ATTEMPT:  1
# TARGET :  138.
# PRED :  104.
# ATTEMPT:  2
# TARGET :  138.
# PRED :  7...
# ATTEMPT:  3
# TARGET :  138.
# PRED :  38..
# ********************
# INPUT :  70.+71.=
# ATTEMPT:  0
# TARGET :  141.
# PRED :  103.
# ATTEMPT:  1
# TARGET :  141.
# PRED :  16..
# ATTEMPT:  2
# TARGET :  141.
# PRED :  93..
# ATTEMPT:  3
# TARGET :  141.
# PRED :  11..
# ********************
# INPUT :  13.+66.=
# ATTEMPT:  0
# TARGET :  79..
# PRED :  778.
# ATTEMPT:  1
# TARGET :  79..
# PRED :  66..
# ATTEMPT:  2
# TARGET :  79..
# PRED :  3...
# ATTEMPT:  3
# TARGET :  79..
# PRED :  113.
# ********************
# INPUT :  99.+88.=
# ATTEMPT:  0
# TARGET :  187.
# PRED :  5...
# ATTEMPT:  1
# TARGET :  187.
# PRED :  160.
# ATTEMPT:  2
# TARGET :  187.
# PRED :  2...
# ATTEMPT:  3
# TARGET :  187.
# PRED :  109.
# ********************
# INPUT :  77.+39.=
# ATTEMPT:  0
# TARGET :  116.
# PRED :  12..
# ATTEMPT:  1
# TARGET :  116.
# PRED :  13..
# ATTEMPT:  2
# TARGET :  116.
# PRED :  64..
# ATTEMPT:  3
# TARGET :  116.
# PRED :  108.
# ********************
# INPUT :  57.+94.=
# ATTEMPT:  0
# TARGET :  151.
# PRED :  155.
# POS: {'1', '5', '.'} and {'7', '9', '1', '.', '+', '5', '4', '='}
# ATTEMPT:  1
# TARGET :  151.
# PRED :  10..
# POS: {'1', '5', '.'} and {'7', '9', '1', '.', '+', '5', '4', '0', '='}
# ATTEMPT:  2
# TARGET :  151.
# PRED :  10..
# POS: {'1', '5', '.'} and {'7', '9', '1', '.', '+', '5', '4', '0', '='}
# ATTEMPT:  3
# TARGET :  151.
# PRED :  8...
# ********************
# INPUT :  87.+66.=
# ATTEMPT:  0
# TARGET :  153.
# PRED :  789.
# ATTEMPT:  1
# TARGET :  153.
# PRED :  9...
# ATTEMPT:  2
# TARGET :  153.
# PRED :  162.
# ATTEMPT:  3
# TARGET :  153.
# PRED :  140.
# ********************
# INPUT :  22.+36.=
# ATTEMPT:  0
# TARGET :  58..
# PRED :  13..
# ATTEMPT:  1
# TARGET :  58..
# PRED :  4...
# ATTEMPT:  2
# TARGET :  58..
# PRED :  3...
# ATTEMPT:  3
# TARGET :  58..
# PRED :  585.
# POS: {'.', '5', '8'} and {'6', '.', '+', '5', '3', '8', '2', '='}
# ********************
# INPUT :  43.+53.=
# ATTEMPT:  0
# TARGET :  96..
# PRED :  97..
# ATTEMPT:  1
# TARGET :  96..
# PRED :  12..
# ATTEMPT:  2
# TARGET :  96..
# PRED :  12..
# ATTEMPT:  3
# TARGET :  96..
# PRED :  2...
# ********************
# INPUT :  43.+54.=
# ATTEMPT:  0
# TARGET :  97..
# PRED :  105.
# ATTEMPT:  1
# TARGET :  97..
# PRED :  51..
# ATTEMPT:  2
# TARGET :  97..
# PRED :  66..
# ATTEMPT:  3
# TARGET :  97..
# PRED :  109.
# ********************
# INPUT :  63.+95.=
# ATTEMPT:  0
# TARGET :  158.
# PRED :  18..
# POS: {'.', '1', '5', '8'} and {'6', '9', '1', '.', '+', '5', '3', '8', '='}
# ATTEMPT:  1
# TARGET :  158.
# PRED :  10..
# ATTEMPT:  2
# TARGET :  158.
# PRED :  4...
# ATTEMPT:  3
# TARGET :  158.
# PRED :  3...
# ********************
# INPUT :  93.+16.=
# ATTEMPT:  0
# TARGET :  109.
# PRED :  7...
# ATTEMPT:  1
# TARGET :  109.
# PRED :  5...
# ATTEMPT:  2
# TARGET :  109.
# PRED :  11..
# ATTEMPT:  3
# TARGET :  109.
# PRED :  9...
# ********************
# INPUT :  84.+76.=
# ATTEMPT:  0
# TARGET :  160.
# PRED :  89..
# ATTEMPT:  1
# TARGET :  160.
# PRED :  9...
# ATTEMPT:  2
# TARGET :  160.
# PRED :  16..
# ATTEMPT:  3
# TARGET :  160.
# PRED :  933.
# ********************
# INPUT :  28.+35.=
# ATTEMPT:  0
# TARGET :  63..
# PRED :  10..
# ATTEMPT:  1
# TARGET :  63..
# PRED :  15..
# ATTEMPT:  2
# TARGET :  63..
# PRED :  115.
# ATTEMPT:  3
# TARGET :  63..
# PRED :  7...
# ********************
# INPUT :  59.+27.=
# ATTEMPT:  0
# TARGET :  86..
# PRED :  10..
# ATTEMPT:  1
# TARGET :  86..
# PRED :  105.
# ATTEMPT:  2
# TARGET :  86..
# PRED :  108.
# ATTEMPT:  3
# TARGET :  86..
# PRED :  11..
# ********************
# INPUT :  31.+73.=
# ATTEMPT:  0
# TARGET :  104.
# PRED :  9...
# ATTEMPT:  1
# TARGET :  104.
# PRED :  66..
# ATTEMPT:  2
# TARGET :  104.
# PRED :  13..
# ATTEMPT:  3
# TARGET :  104.
# PRED :  3...
# ********************
# INPUT :  91.+40.=
# ATTEMPT:  0
# TARGET :  131.
# PRED :  15..
# ATTEMPT:  1
# TARGET :  131.
# PRED :  48..
# ATTEMPT:  2
# TARGET :  131.
# PRED :  11..
# ATTEMPT:  3
# TARGET :  131.
# PRED :  65..
# ********************
# INPUT :  38.+51.=
# ATTEMPT:  0
# TARGET :  89..
# PRED :  10..
# ATTEMPT:  1
# TARGET :  89..
# PRED :  9...
# POS: {'.', '9', '8'} and {'1', '9', '.', '+', '5', '3', '8', '='}
# ATTEMPT:  2
# TARGET :  89..
# PRED :  12..
# ATTEMPT:  3
# TARGET :  89..
# PRED :  10..
# ********************
# INPUT :  98.+16.=
# ATTEMPT:  0
# TARGET :  114.
# PRED :  11..
# ATTEMPT:  1
# TARGET :  114.
# PRED :  14..
# POS: {'4', '1', '.'} and {'6', '9', '1', '.', '+', '4', '8', '='}
# ATTEMPT:  2
# TARGET :  114.
# PRED :  9...
# ATTEMPT:  3
# TARGET :  114.
# PRED :  12..
# ********************
# INPUT :  98.+64.=
# ATTEMPT:  0
# TARGET :  162.
# PRED :  686.
# ATTEMPT:  1
# TARGET :  162.
# PRED :  9...
# ATTEMPT:  2
# TARGET :  162.
# PRED :  7...
# ATTEMPT:  3
# TARGET :  162.
# PRED :  86..
# ********************
# INPUT :  96.+27.=
# ATTEMPT:  0
# TARGET :  123.
# PRED :  7...
# ATTEMPT:  1
# TARGET :  123.
# PRED :  121.
# ATTEMPT:  2
# TARGET :  123.
# PRED :  8...
# ATTEMPT:  3
# TARGET :  123.
# PRED :  12..
# ********************
# INPUT :  51.+14.=
# ATTEMPT:  0
# TARGET :  65..
# PRED :  7...
# ATTEMPT:  1
# TARGET :  65..
# PRED :  150.
# ATTEMPT:  2
# TARGET :  65..
# PRED :  96..
# POS: {'6', '5', '.'} and {'6', '1', '9', '.', '+', '5', '4', '='}
# ATTEMPT:  3
# TARGET :  65..
# PRED :  641.
# POS: {'6', '5', '.'} and {'6', '1', '.', '+', '5', '4', '='}
# ********************
# INPUT :  15.+30.=
# ATTEMPT:  0
# TARGET :  45..
# PRED :  7...
# ATTEMPT:  1
# TARGET :  45..
# PRED :  108.
# ATTEMPT:  2
# TARGET :  45..
# PRED :  10..
# ATTEMPT:  3
# TARGET :  45..
# PRED :  6...
# ********************
# INPUT :  51.+16.=
# ATTEMPT:  0
# TARGET :  67..
# PRED :  9...
# ATTEMPT:  1
# TARGET :  67..
# PRED :  95..
# ATTEMPT:  2
# TARGET :  67..
# PRED :  101.
# ATTEMPT:  3
# TARGET :  67..
# PRED :  3...
# ********************
# INPUT :  49.+61.=
# ATTEMPT:  0
# TARGET :  110.
# PRED :  4...
# ATTEMPT:  1
# TARGET :  110.
# PRED :  109.
# POS: {'1', '0', '.'} and {'6', '9', '1', '.', '+', '4', '0', '='}
# ATTEMPT:  2
# TARGET :  110.
# PRED :  869.
# ATTEMPT:  3
# TARGET :  110.
# PRED :  10..
# POS: {'1', '0', '.'} and {'6', '9', '1', '.', '+', '4', '0', '='}
# ********************
# INPUT :  18.+61.=
# ATTEMPT:  0
# TARGET :  79..
# PRED :  18..
# ATTEMPT:  1
# TARGET :  79..
# PRED :  64..
# ATTEMPT:  2
# TARGET :  79..
# PRED :  9...
# ATTEMPT:  3
# TARGET :  79..
# PRED :  114.
# ********************
# INPUT :  87.+74.=
# ATTEMPT:  0
# TARGET :  161.
# PRED :  4...
# ATTEMPT:  1
# TARGET :  161.
# PRED :  3...
# ATTEMPT:  2
# TARGET :  161.
# PRED :  9...
# ATTEMPT:  3
# TARGET :  161.
# PRED :  9...
# ********************
# INPUT :  78.+73.=
# ATTEMPT:  0
# TARGET :  151.
# PRED :  117.
# ATTEMPT:  1
# TARGET :  151.
# PRED :  9...
# ATTEMPT:  2
# TARGET :  151.
# PRED :  16..
# ATTEMPT:  3
# TARGET :  151.
# PRED :  73..
# ********************
# INPUT :  72.+83.=
# ATTEMPT:  0
# TARGET :  155.
# PRED :  75..
# ATTEMPT:  1
# TARGET :  155.
# PRED :  145.
# POS: {'1', '5', '.'} and {'7', '1', '.', '+', '5', '3', '4', '8', '2', '='}
# ATTEMPT:  2
# TARGET :  155.
# PRED :  9...
# ATTEMPT:  3
# TARGET :  155.
# PRED :  6...
# ********************
# INPUT :  35.+48.=
# ATTEMPT:  0
# TARGET :  83..
# PRED :  667.
# POS: {'.', '3', '8'} and {'6', '7', '.', '+', '5', '3', '4', '8', '='}
# ATTEMPT:  1
# TARGET :  83..
# PRED :  159.
# POS: {'.', '3', '8'} and {'1', '9', '.', '+', '5', '3', '4', '8', '='}
# ATTEMPT:  2
# TARGET :  83..
# PRED :  865.
# POS: {'.', '3', '8'} and {'6', '.', '+', '5', '3', '4', '8', '='}
# ATTEMPT:  3
# TARGET :  83..
# PRED :  30..
# POS: {'.', '3', '8'} and {'.', '+', '5', '3', '4', '0', '8', '='}
# ********************
# INPUT :  15.+50.=
# ATTEMPT:  0
# TARGET :  65..
# PRED :  126.
# POS: {'6', '5', '.'} and {'6', '1', '.', '+', '5', '0', '2', '='}
# ATTEMPT:  1
# TARGET :  65..
# PRED :  74..
# ATTEMPT:  2
# TARGET :  65..
# PRED :  124.
# ATTEMPT:  3
# TARGET :  65..
# PRED :  2...
# ********************
# INPUT :  62.+43.=
# ATTEMPT:  0
# TARGET :  105.
# PRED :  15..
# ATTEMPT:  1
# TARGET :  105.
# PRED :  10..
# ATTEMPT:  2
# TARGET :  105.
# PRED :  134.
# ATTEMPT:  3
# TARGET :  105.
# PRED :  7...
# ********************
# INPUT :  45.+99.=
# ATTEMPT:  0
# TARGET :  144.
# PRED :  9...
# ATTEMPT:  1
# TARGET :  144.
# PRED :  11..
# POS: {'4', '1', '.'} and {'9', '1', '.', '+', '5', '4', '='}
# ATTEMPT:  2
# TARGET :  144.
# PRED :  62..
# ATTEMPT:  3
# TARGET :  144.
# PRED :  45..
# ********************
# INPUT :  89.+11.=
# ATTEMPT:  0
# TARGET :  100.
# PRED :  17..
# ATTEMPT:  1
# TARGET :  100.
# PRED :  114.
# ATTEMPT:  2
# TARGET :  100.
# PRED :  102.
# POS: {'1', '0', '.'} and {'9', '1', '.', '+', '0', '8', '2', '='}
# ATTEMPT:  3
# TARGET :  100.
# PRED :  13..
# ********************
# INPUT :  42.+57.=
# ATTEMPT:  0
# TARGET :  99..
# PRED :  5...
# ATTEMPT:  1
# TARGET :  99..
# PRED :  8...
# ATTEMPT:  2
# TARGET :  99..
# PRED :  76..
# ATTEMPT:  3
# TARGET :  99..
# PRED :  126.
# ********************
# INPUT :  36.+69.=
# ATTEMPT:  0
# TARGET :  105.
# PRED :  98..
# ATTEMPT:  1
# TARGET :  105.
# PRED :  13..
# ATTEMPT:  2
# TARGET :  105.
# PRED :  18..
# ATTEMPT:  3
# TARGET :  105.
# PRED :  14..
# ********************
# INPUT :  55.+22.=
# ATTEMPT:  0
# TARGET :  77..
# PRED :  5...
# ATTEMPT:  1
# TARGET :  77..
# PRED :  159.
# ATTEMPT:  2
# TARGET :  77..
# PRED :  10..
# ATTEMPT:  3
# TARGET :  77..
# PRED :  92..
# ********************
# INPUT :  88.+92.=
# ATTEMPT:  0
# TARGET :  180.
# PRED :  8...
# ATTEMPT:  1
# TARGET :  180.
# PRED :  546.
# ATTEMPT:  2
# TARGET :  180.
# PRED :  15..
# ATTEMPT:  3
# TARGET :  180.
# PRED :  7...
# ********************
# INPUT :  95.+43.=
# ATTEMPT:  0
# TARGET :  138.
# PRED :  8...
# ATTEMPT:  1
# TARGET :  138.
# PRED :  8...
# ATTEMPT:  2
# TARGET :  138.
# PRED :  3...
# ATTEMPT:  3
# TARGET :  138.
# PRED :  91..
# ********************
# INPUT :  38.+28.=
# ATTEMPT:  0
# TARGET :  66..
# PRED :  7...
# ATTEMPT:  1
# TARGET :  66..
# PRED :  15..
# ATTEMPT:  2
# TARGET :  66..
# PRED :  450.
# ATTEMPT:  3
# TARGET :  66..
# PRED :  18..
# ********************
# INPUT :  45.+57.=
# ATTEMPT:  0
# TARGET :  102.
# PRED :  11..
# ATTEMPT:  1
# TARGET :  102.
# PRED :  10..
# ATTEMPT:  2
# TARGET :  102.
# PRED :  1...
# ATTEMPT:  3
# TARGET :  102.
# PRED :  14..
# ********************
# INPUT :  89.+46.=
# ATTEMPT:  0
# TARGET :  135.
# PRED :  18..
# ATTEMPT:  1
# TARGET :  135.
# PRED :  13..
# ATTEMPT:  2
# TARGET :  135.
# PRED :  13..
# ATTEMPT:  3
# TARGET :  135.
# PRED :  3...
# ********************
# INPUT :  59.+90.=
# ATTEMPT:  0
# TARGET :  149.
# PRED :  10..
# ATTEMPT:  1
# TARGET :  149.
# PRED :  140.
# POS: {'4', '9', '1', '.'} and {'9', '1', '.', '+', '5', '4', '0', '='}
# ATTEMPT:  2
# TARGET :  149.
# PRED :  10..
# ATTEMPT:  3
# TARGET :  149.
# PRED :  18..
# ********************
# INPUT :  61.+14.=
# ATTEMPT:  0
# TARGET :  75..
# PRED :  13..
# ATTEMPT:  1
# TARGET :  75..
# PRED :  14..
# ATTEMPT:  2
# TARGET :  75..
# PRED :  669.
# ATTEMPT:  3
# TARGET :  75..
# PRED :  8...
# ********************
# INPUT :  39.+69.=
# ATTEMPT:  0
# TARGET :  108.
# PRED :  6...
# ATTEMPT:  1
# TARGET :  108.
# PRED :  10..
# ATTEMPT:  2
# TARGET :  108.
# PRED :  130.
# ATTEMPT:  3
# TARGET :  108.
# PRED :  11..
# ********************
# INPUT :  73.+73.=
# ATTEMPT:  0
# TARGET :  146.
# PRED :  8...
# ATTEMPT:  1
# TARGET :  146.
# PRED :  131.
# ATTEMPT:  2
# TARGET :  146.
# PRED :  15..
# ATTEMPT:  3
# TARGET :  146.
# PRED :  136.
# ********************
# INPUT :  84.+16.=
# ATTEMPT:  0
# TARGET :  100.
# PRED :  16..
# ATTEMPT:  1
# TARGET :  100.
# PRED :  4...
# ATTEMPT:  2
# TARGET :  100.
# PRED :  17..
# ATTEMPT:  3
# TARGET :  100.
# PRED :  107.
# POS: {'1', '0', '.'} and {'6', '7', '1', '.', '+', '4', '0', '8', '='}
# ********************
# INPUT :  29.+17.=
# ATTEMPT:  0
# TARGET :  46..
# PRED :  0...
# ATTEMPT:  1
# TARGET :  46..
# PRED :  11..
# ATTEMPT:  2
# TARGET :  46..
# PRED :  140.
# ATTEMPT:  3
# TARGET :  46..
# PRED :  5...
# ********************
# INPUT :  76.+92.=
# ATTEMPT:  0
# TARGET :  168.
# PRED :  8...
# ATTEMPT:  1
# TARGET :  168.
# PRED :  126.
# ATTEMPT:  2
# TARGET :  168.
# PRED :  6...
# ATTEMPT:  3
# TARGET :  168.
# PRED :  5...
# ********************
# INPUT :  28.+65.=
# ATTEMPT:  0
# TARGET :  93..
# PRED :  93..
# POS: {'.', '9', '3'} and {'6', '9', '.', '+', '5', '3', '8', '2', '='}
# ATTEMPT:  1
# TARGET :  93..
# PRED :  9...
# ATTEMPT:  2
# TARGET :  93..
# PRED :  111.
# ATTEMPT:  3
# TARGET :  93..
# PRED :  65..
# ********************
# INPUT :  96.+29.=
# ATTEMPT:  0
# TARGET :  125.
# PRED :  1...
# ATTEMPT:  1
# TARGET :  125.
# PRED :  131.
# ATTEMPT:  2
# TARGET :  125.
# PRED :  6...
# ATTEMPT:  3
# TARGET :  125.
# PRED :  2...
# ********************
# INPUT :  49.+86.=
# ATTEMPT:  0
# TARGET :  135.
# PRED :  496.
# ATTEMPT:  1
# TARGET :  135.
# PRED :  14..
# ATTEMPT:  2
# TARGET :  135.
# PRED :  936.
# ATTEMPT:  3
# TARGET :  135.
# PRED :  15..
# ********************
# INPUT :  88.+21.=
# ATTEMPT:  0
# TARGET :  109.
# PRED :  13..
# ATTEMPT:  1
# TARGET :  109.
# PRED :  5...
# ATTEMPT:  2
# TARGET :  109.
# PRED :  1...
# ATTEMPT:  3
# TARGET :  109.
# PRED :  10..
# ********************
# INPUT :  10.+13.=
# ATTEMPT:  0
# TARGET :  23..
# PRED :  11..
# ATTEMPT:  1
# TARGET :  23..
# PRED :  5...
# ATTEMPT:  2
# TARGET :  23..
# PRED :  11..
# ATTEMPT:  3
# TARGET :  23..
# PRED :  8...
# ********************
# INPUT :  51.+15.=
# ATTEMPT:  0
# TARGET :  66..
# PRED :  71..
# ATTEMPT:  1
# TARGET :  66..
# PRED :  12..
# ATTEMPT:  2
# TARGET :  66..
# PRED :  7...
# ATTEMPT:  3
# TARGET :  66..
# PRED :  14..
# ********************
# INPUT :  70.+24.=
# ATTEMPT:  0
# TARGET :  94..
# PRED :  117.
# ATTEMPT:  1
# TARGET :  94..
# PRED :  75..
# ATTEMPT:  2
# TARGET :  94..
# PRED :  8...
# ATTEMPT:  3
# TARGET :  94..
# PRED :  907.
# POS: {'4', '9', '.'} and {'7', '9', '.', '+', '4', '0', '2', '='}
# ********************
# INPUT :  98.+89.=
# ATTEMPT:  0
# TARGET :  187.
# PRED :  8...
# ATTEMPT:  1
# TARGET :  187.
# PRED :  67..
# ATTEMPT:  2
# TARGET :  187.
# PRED :  7...
# ATTEMPT:  3
# TARGET :  187.
# PRED :  12..
# ********************
# INPUT :  34.+44.=
# ATTEMPT:  0
# TARGET :  78..
# PRED :  156.
# ATTEMPT:  1
# TARGET :  78..
# PRED :  10..
# ATTEMPT:  2
# TARGET :  78..
# PRED :  10..
# ATTEMPT:  3
# TARGET :  78..
# PRED :  78..
# POS: {'7', '.', '8'} and {'7', '.', '+', '3', '4', '8', '='}
# ********************
# INPUT :  42.+61.=
# ATTEMPT:  0
# TARGET :  103.
# PRED :  7...
# ATTEMPT:  1
# TARGET :  103.
# PRED :  84..
# ATTEMPT:  2
# TARGET :  103.
# PRED :  47..
# ATTEMPT:  3
# TARGET :  103.
# PRED :  10..
# ********************
# INPUT :  18.+93.=
# ATTEMPT:  0
# TARGET :  111.
# PRED :  9...
# POS: {'1', '.'} and {'9', '1', '.', '+', '3', '8', '='}
# ATTEMPT:  1
# TARGET :  111.
# PRED :  110.
# POS: {'1', '.'} and {'9', '1', '.', '+', '3', '0', '8', '='}
# ATTEMPT:  2
# TARGET :  111.
# PRED :  76..
# POS: {'1', '.'} and {'7', '6', '9', '1', '.', '+', '3', '8', '='}
# ATTEMPT:  3
# TARGET :  111.
# PRED :  134.
# POS: {'1', '.'} and {'9', '1', '.', '+', '3', '4', '8', '='}
# ********************
# INPUT :  82.+50.=
# ATTEMPT:  0
# TARGET :  132.
# PRED :  76..
# ATTEMPT:  1
# TARGET :  132.
# PRED :  17..
# ATTEMPT:  2
# TARGET :  132.
# PRED :  6...
# ATTEMPT:  3
# TARGET :  132.
# PRED :  7...
# ********************
# INPUT :  42.+52.=
# ATTEMPT:  0
# TARGET :  94..
# PRED :  0...
# ATTEMPT:  1
# TARGET :  94..
# PRED :  107.
# ATTEMPT:  2
# TARGET :  94..
# PRED :  2...
# ATTEMPT:  3
# TARGET :  94..
# PRED :  610.
# ********************
# INPUT :  34.+63.=
# ATTEMPT:  0
# TARGET :  97..
# PRED :  4...
# ATTEMPT:  1
# TARGET :  97..
# PRED :  123.
# ATTEMPT:  2
# TARGET :  97..
# PRED :  558.
# ATTEMPT:  3
# TARGET :  97..
# PRED :  103.
# ********************
# INPUT :  78.+63.=
# ATTEMPT:  0
# TARGET :  141.
# PRED :  8...
# ATTEMPT:  1
# TARGET :  141.
# PRED :  118.
# ATTEMPT:  2
# TARGET :  141.
# PRED :  11..
# ATTEMPT:  3
# TARGET :  141.
# PRED :  9...
# ********************
# INPUT :  14.+95.=
# ATTEMPT:  0
# TARGET :  109.
# PRED :  12..
# ATTEMPT:  1
# TARGET :  109.
# PRED :  105.
# POS: {'9', '1', '0', '.'} and {'9', '1', '.', '+', '5', '4', '0', '='}
# ATTEMPT:  2
# TARGET :  109.
# PRED :  16..
# ATTEMPT:  3
# TARGET :  109.
# PRED :  9...
# ********************
# INPUT :  15.+76.=
# ATTEMPT:  0
# TARGET :  91..
# PRED :  16..
# ATTEMPT:  1
# TARGET :  91..
# PRED :  3...
# ATTEMPT:  2
# TARGET :  91..
# PRED :  8...
# ATTEMPT:  3
# TARGET :  91..
# PRED :  96..
# POS: {'1', '9', '.'} and {'7', '6', '1', '9', '.', '+', '5', '='}
# ********************
# INPUT :  16.+12.=
# ATTEMPT:  0
# TARGET :  28..
# PRED :  150.
# ATTEMPT:  1
# TARGET :  28..
# PRED :  15..
# ATTEMPT:  2
# TARGET :  28..
# PRED :  7...
# ATTEMPT:  3
# TARGET :  28..
# PRED :  8...
# POS: {'.', '2', '8'} and {'6', '1', '.', '+', '8', '2', '='}
# ********************
# INPUT :  31.+13.=
# ATTEMPT:  0
# TARGET :  44..
# PRED :  9...
# ATTEMPT:  1
# TARGET :  44..
# PRED :  945.
# POS: {'4', '.'} and {'1', '9', '.', '+', '5', '3', '4', '='}
# ATTEMPT:  2
# TARGET :  44..
# PRED :  107.
# ATTEMPT:  3
# TARGET :  44..
# PRED :  8...
# ********************
# INPUT :  12.+70.=
# ATTEMPT:  0
# TARGET :  82..
# PRED :  8...
# POS: {'.', '2', '8'} and {'7', '1', '.', '+', '0', '8', '2', '='}
# ATTEMPT:  1
# TARGET :  82..
# PRED :  46..
# ATTEMPT:  2
# TARGET :  82..
# PRED :  10..
# ATTEMPT:  3
# TARGET :  82..
# PRED :  7...
# ********************
# INPUT :  23.+62.=
# ATTEMPT:  0
# TARGET :  85..
# PRED :  8...
# ATTEMPT:  1
# TARGET :  85..
# PRED :  9...
# ATTEMPT:  2
# TARGET :  85..
# PRED :  6...
# ATTEMPT:  3
# TARGET :  85..
# PRED :  98..
# ********************
# INPUT :  39.+11.=
# ATTEMPT:  0
# TARGET :  50..
# PRED :  13..
# ATTEMPT:  1
# TARGET :  50..
# PRED :  13..
# ATTEMPT:  2
# TARGET :  50..
# PRED :  15..
# ATTEMPT:  3
# TARGET :  50..
# PRED :  14..
# ********************
# INPUT :  93.+96.=
# ATTEMPT:  0
# TARGET :  189.
# PRED :  10..
# ATTEMPT:  1
# TARGET :  189.
# PRED :  155.
# ATTEMPT:  2
# TARGET :  189.
# PRED :  30..
# ATTEMPT:  3
# TARGET :  189.
# PRED :  309.
# ********************
# INPUT :  89.+77.=
# ATTEMPT:  0
# TARGET :  166.
# PRED :  10..
# ATTEMPT:  1
# TARGET :  166.
# PRED :  864.
# ATTEMPT:  2
# TARGET :  166.
# PRED :  12..
# ATTEMPT:  3
# TARGET :  166.
# PRED :  97..
# ********************
# INPUT :  28.+51.=
# ATTEMPT:  0
# TARGET :  79..
# PRED :  14..
# ATTEMPT:  1
# TARGET :  79..
# PRED :  11..
# ATTEMPT:  2
# TARGET :  79..
# PRED :  139.
# ATTEMPT:  3
# TARGET :  79..
# PRED :  56..
# ********************
# INPUT :  10.+17.=
# ATTEMPT:  0
# TARGET :  27..
# PRED :  13..
# ATTEMPT:  1
# TARGET :  27..
# PRED :  69..
# ATTEMPT:  2
# TARGET :  27..
# PRED :  86..
# ATTEMPT:  3
# TARGET :  27..
# PRED :  13..
# ********************
# INPUT :  36.+65.=
# ATTEMPT:  0
# TARGET :  101.
# PRED :  673.
# ATTEMPT:  1
# TARGET :  101.
# PRED :  6...
# ATTEMPT:  2
# TARGET :  101.
# PRED :  7...
# ATTEMPT:  3
# TARGET :  101.
# PRED :  15..
# ********************
# INPUT :  85.+81.=
# ATTEMPT:  0
# TARGET :  166.
# PRED :  107.
# ATTEMPT:  1
# TARGET :  166.
# PRED :  146.
# POS: {'6', '1', '.'} and {'6', '1', '.', '+', '5', '4', '8', '='}
# ATTEMPT:  2
# TARGET :  166.
# PRED :  6...
# POS: {'6', '1', '.'} and {'6', '1', '.', '+', '5', '8', '='}
# ATTEMPT:  3
# TARGET :  166.
# PRED :  88..
# ********************
# INPUT :  84.+89.=
# ATTEMPT:  0
# TARGET :  173.
# PRED :  126.
# ATTEMPT:  1
# TARGET :  173.
# PRED :  61..
# ATTEMPT:  2
# TARGET :  173.
# PRED :  13..
# ATTEMPT:  3
# TARGET :  173.
# PRED :  13..
# ********************
# INPUT :  37.+76.=
# ATTEMPT:  0
# TARGET :  113.
# PRED :  13..
# POS: {'.', '1', '3'} and {'6', '7', '1', '.', '+', '3', '='}
# ATTEMPT:  1
# TARGET :  113.
# PRED :  102.
# POS: {'.', '1', '3'} and {'6', '7', '1', '.', '+', '3', '0', '2', '='}
# ATTEMPT:  2
# TARGET :  113.
# PRED :  15..
# POS: {'.', '1', '3'} and {'6', '7', '1', '.', '+', '5', '3', '='}
# ATTEMPT:  3
# TARGET :  113.
# PRED :  74..
# ********************
# INPUT :  84.+74.=
# ATTEMPT:  0
# TARGET :  158.
# PRED :  11..
# ATTEMPT:  1
# TARGET :  158.
# PRED :  85..
# ATTEMPT:  2
# TARGET :  158.
# PRED :  56..
# ATTEMPT:  3
# TARGET :  158.
# PRED :  147.
# ********************
# INPUT :  88.+44.=
# ATTEMPT:  0
# TARGET :  132.
# PRED :  9...
# ATTEMPT:  1
# TARGET :  132.
# PRED :  159.
# ATTEMPT:  2
# TARGET :  132.
# PRED :  142.
# ATTEMPT:  3
# TARGET :  132.
# PRED :  74..
# ********************
# INPUT :  44.+15.=
# ATTEMPT:  0
# TARGET :  59..
# PRED :  6...
# ATTEMPT:  1
# TARGET :  59..
# PRED :  13..
# ATTEMPT:  2
# TARGET :  59..
# PRED :  1...
# ATTEMPT:  3
# TARGET :  59..
# PRED :  10..
# ********************
# INPUT :  84.+93.=
# ATTEMPT:  0
# TARGET :  177.
# PRED :  7...
# ATTEMPT:  1
# TARGET :  177.
# PRED :  7...
# ATTEMPT:  2
# TARGET :  177.
# PRED :  7...
# ATTEMPT:  3
# TARGET :  177.
# PRED :  6...
# ********************
# INPUT :  53.+57.=
# ATTEMPT:  0
# TARGET :  110.
# PRED :  142.
# ATTEMPT:  1
# TARGET :  110.
# PRED :  15..
# ATTEMPT:  2
# TARGET :  110.
# PRED :  100.
# POS: {'1', '0', '.'} and {'7', '1', '.', '+', '5', '3', '0', '='}
# ATTEMPT:  3
# TARGET :  110.
# PRED :  116.
# ********************
# INPUT :  97.+62.=
# ATTEMPT:  0
# TARGET :  159.
# PRED :  11..
# ATTEMPT:  1
# TARGET :  159.
# PRED :  11..
# ATTEMPT:  2
# TARGET :  159.
# PRED :  9...
# ATTEMPT:  3
# TARGET :  159.
# PRED :  14..
# ********************
# INPUT :  31.+41.=
# ATTEMPT:  0
# TARGET :  72..
# PRED :  86..
# ATTEMPT:  1
# TARGET :  72..
# PRED :  16..
# ATTEMPT:  2
# TARGET :  72..
# PRED :  9...
# ATTEMPT:  3
# TARGET :  72..
# PRED :  94..
# ********************
# INPUT :  18.+93.=
# ATTEMPT:  0
# TARGET :  111.
# PRED :  16..
# POS: {'1', '.'} and {'6', '9', '1', '.', '+', '3', '8', '='}
# ATTEMPT:  1
# TARGET :  111.
# PRED :  8...
# POS: {'1', '.'} and {'9', '1', '.', '+', '3', '8', '='}
# ATTEMPT:  2
# TARGET :  111.
# PRED :  7...
# POS: {'1', '.'} and {'7', '9', '1', '.', '+', '3', '8', '='}
# ATTEMPT:  3
# TARGET :  111.
# PRED :  148.
# POS: {'1', '.'} and {'9', '1', '.', '+', '3', '4', '8', '='}
# ********************
# INPUT :  47.+73.=
# ATTEMPT:  0
# TARGET :  120.
# PRED :  7...
# ATTEMPT:  1
# TARGET :  120.
# PRED :  3...
# ATTEMPT:  2
# TARGET :  120.
# PRED :  139.
# ATTEMPT:  3
# TARGET :  120.
# PRED :  120.
# POS: {'2', '1', '0', '.'} and {'7', '1', '.', '+', '3', '4', '0', '2', '='}
# ********************
# INPUT :  30.+21.=
# ATTEMPT:  0
# TARGET :  51..
# PRED :  18..
# ATTEMPT:  1
# TARGET :  51..
# PRED :  156.
# POS: {'1', '5', '.'} and {'6', '1', '.', '+', '5', '3', '0', '2', '='}
# ATTEMPT:  2
# TARGET :  51..
# PRED :  125.
# POS: {'1', '5', '.'} and {'1', '.', '+', '5', '3', '0', '2', '='}
# ATTEMPT:  3
# TARGET :  51..
# PRED :  3...
# ********************
# INPUT :  24.+52.=
# ATTEMPT:  0
# TARGET :  76..
# PRED :  1...
# ATTEMPT:  1
# TARGET :  76..
# PRED :  11..
# ATTEMPT:  2
# TARGET :  76..
# PRED :  14..
# ATTEMPT:  3
# TARGET :  76..
# PRED :  16..
# ********************
# INPUT :  352+747=
# ATTEMPT:  0
# TARGET :  1099
# PRED :  69..
# ATTEMPT:  1
# TARGET :  1099
# PRED :  8...
# ATTEMPT:  2
# TARGET :  1099
# PRED :  62..
# ATTEMPT:  3
# TARGET :  1099
# PRED :  181.
# ********************
# INPUT :  674+478=
# ATTEMPT:  0
# TARGET :  1152
# PRED :  5...
# ATTEMPT:  1
# TARGET :  1152
# PRED :  3...
# ATTEMPT:  2
# TARGET :  1152
# PRED :  3...
# ATTEMPT:  3
# TARGET :  1152
# PRED :  14..
# ********************
# INPUT :  280+511=
# ATTEMPT:  0
# TARGET :  791.
# PRED :  17..
# ATTEMPT:  1
# TARGET :  791.
# PRED :  36..
# ATTEMPT:  2
# TARGET :  791.
# PRED :  12..
# ATTEMPT:  3
# TARGET :  791.
# PRED :  106.
# ********************
# INPUT :  195+291=
# ATTEMPT:  0
# TARGET :  486.
# PRED :  147.
# ATTEMPT:  1
# TARGET :  486.
# PRED :  7...
# ATTEMPT:  2
# TARGET :  486.
# PRED :  7...
# ATTEMPT:  3
# TARGET :  486.
# PRED :  73..
# ********************
# INPUT :  818+156=
# ATTEMPT:  0
# TARGET :  974.
# PRED :  9...
# ATTEMPT:  1
# TARGET :  974.
# PRED :  14..
# ATTEMPT:  2
# TARGET :  974.
# PRED :  6...
# ATTEMPT:  3
# TARGET :  974.
# PRED :  1...
# ********************
# INPUT :  150+232=
# ATTEMPT:  0
# TARGET :  382.
# PRED :  2...
# ATTEMPT:  1
# TARGET :  382.
# PRED :  115.
# ATTEMPT:  2
# TARGET :  382.
# PRED :  5...
# ATTEMPT:  3
# TARGET :  382.
# PRED :  172.
# ********************
# INPUT :  181+752=
# ATTEMPT:  0
# TARGET :  933.
# PRED :  584.
# ATTEMPT:  1
# TARGET :  933.
# PRED :  835.
# ATTEMPT:  2
# TARGET :  933.
# PRED :  15..
# ATTEMPT:  3
# TARGET :  933.
# PRED :  926.
# ********************
# INPUT :  961+693=
# ATTEMPT:  0
# TARGET :  1654
# PRED :  8...
# ATTEMPT:  1
# TARGET :  1654
# PRED :  97..
# ATTEMPT:  2
# TARGET :  1654
# PRED :  8...
# ATTEMPT:  3
# TARGET :  1654
# PRED :  53..
# ********************
# INPUT :  132+718=
# ATTEMPT:  0
# TARGET :  850.
# PRED :  88..
# ATTEMPT:  1
# TARGET :  850.
# PRED :  7...
# ATTEMPT:  2
# TARGET :  850.
# PRED :  8...
# ATTEMPT:  3
# TARGET :  850.
# PRED :  87..
# ********************
# INPUT :  382+760=
# ATTEMPT:  0
# TARGET :  1142
# PRED :  11..
# ATTEMPT:  1
# TARGET :  1142
# PRED :  13..
# ATTEMPT:  2
# TARGET :  1142
# PRED :  4...
# ATTEMPT:  3
# TARGET :  1142
# PRED :  109.
# ********************
# INPUT :  665+342=
# ATTEMPT:  0
# TARGET :  1007
# PRED :  104.
# ATTEMPT:  1
# TARGET :  1007
# PRED :  86..
# ATTEMPT:  2
# TARGET :  1007
# PRED :  4...
# ATTEMPT:  3
# TARGET :  1007
# PRED :  943.
# ********************
# INPUT :  515+712=
# ATTEMPT:  0
# TARGET :  1227
# PRED :  13..
# POS: {'7', '2', '1'} and {'7', '1', '.', '+', '5', '3', '2', '='}
# ATTEMPT:  1
# TARGET :  1227
# PRED :  6...
# POS: {'7', '2', '1'} and {'7', '6', '1', '.', '+', '5', '2', '='}
# ATTEMPT:  2
# TARGET :  1227
# PRED :  135.
# POS: {'7', '2', '1'} and {'7', '1', '.', '+', '5', '3', '2', '='}
# ATTEMPT:  3
# TARGET :  1227
# PRED :  718.
# POS: {'7', '2', '1'} and {'7', '1', '.', '+', '5', '8', '2', '='}
# ********************
# INPUT :  770+639=
# ATTEMPT:  0
# TARGET :  1409
# PRED :  16..
# ATTEMPT:  1
# TARGET :  1409
# PRED :  6...
# ATTEMPT:  2
# TARGET :  1409
# PRED :  53..
# ATTEMPT:  3
# TARGET :  1409
# PRED :  14..
# POS: {'4', '9', '1', '0'} and {'6', '7', '9', '1', '.', '+', '3', '4', '0', '='}
# ********************
# INPUT :  679+190=
# ATTEMPT:  0
# TARGET :  869.
# PRED :  4...
# ATTEMPT:  1
# TARGET :  869.
# PRED :  13..
# ATTEMPT:  2
# TARGET :  869.
# PRED :  4...
# ATTEMPT:  3
# TARGET :  869.
# PRED :  17..
# ********************
# INPUT :  363+105=
# ATTEMPT:  0
# TARGET :  468.
# PRED :  16..
# ATTEMPT:  1
# TARGET :  468.
# PRED :  9...
# ATTEMPT:  2
# TARGET :  468.
# PRED :  8...
# ATTEMPT:  3
# TARGET :  468.
# PRED :  15..
# ********************
# INPUT :  807+929=
# ATTEMPT:  0
# TARGET :  1736
# PRED :  10..
# ATTEMPT:  1
# TARGET :  1736
# PRED :  5...
# ATTEMPT:  2
# TARGET :  1736
# PRED :  6...
# ATTEMPT:  3
# TARGET :  1736
# PRED :  4...
# ********************
# INPUT :  664+266=
# ATTEMPT:  0
# TARGET :  930.
# PRED :  653.
# ATTEMPT:  1
# TARGET :  930.
# PRED :  7...
# ATTEMPT:  2
# TARGET :  930.
# PRED :  8...
# ATTEMPT:  3
# TARGET :  930.
# PRED :  9...
# ********************
# INPUT :  967+183=
# ATTEMPT:  0
# TARGET :  1150
# PRED :  815.
# ATTEMPT:  1
# TARGET :  1150
# PRED :  5...
# ATTEMPT:  2
# TARGET :  1150
# PRED :  62..
# ATTEMPT:  3
# TARGET :  1150
# PRED :  11..
# ********************
# INPUT :  686+792=
# ATTEMPT:  0
# TARGET :  1478
# PRED :  16..
# ATTEMPT:  1
# TARGET :  1478
# PRED :  15..
# ATTEMPT:  2
# TARGET :  1478
# PRED :  7...
# ATTEMPT:  3
# TARGET :  1478
# PRED :  8...
# ********************
# INPUT :  629+594=
# ATTEMPT:  0
# TARGET :  1223
# PRED :  15..
# ATTEMPT:  1
# TARGET :  1223
# PRED :  102.
# ATTEMPT:  2
# TARGET :  1223
# PRED :  10..
# ATTEMPT:  3
# TARGET :  1223
# PRED :  18..
# ********************
# INPUT :  334+658=
# ATTEMPT:  0
# TARGET :  992.
# PRED :  12..
# ATTEMPT:  1
# TARGET :  992.
# PRED :  9...
# ATTEMPT:  2
# TARGET :  992.
# PRED :  113.
# ATTEMPT:  3
# TARGET :  992.
# PRED :  10..
# ********************
# INPUT :  775+805=
# ATTEMPT:  0
# TARGET :  1580
# PRED :  117.
# POS: {'0', '1', '5', '8'} and {'7', '1', '.', '+', '5', '0', '8', '='}
# ATTEMPT:  1
# TARGET :  1580
# PRED :  6...
# ATTEMPT:  2
# TARGET :  1580
# PRED :  836.
# ATTEMPT:  3
# TARGET :  1580
# PRED :  7...
# ********************
# INPUT :  891+594=
# ATTEMPT:  0
# TARGET :  1485
# PRED :  102.
# POS: {'4', '1', '5', '8'} and {'1', '9', '.', '+', '5', '4', '0', '8', '2', '='}
# ATTEMPT:  1
# TARGET :  1485
# PRED :  4...
# POS: {'4', '1', '5', '8'} and {'1', '9', '.', '+', '5', '4', '8', '='}
# ATTEMPT:  2
# TARGET :  1485
# PRED :  13..
# POS: {'4', '1', '5', '8'} and {'1', '9', '.', '+', '5', '3', '4', '8', '='}
# ATTEMPT:  3
# TARGET :  1485
# PRED :  786.
# POS: {'4', '1', '5', '8'} and {'7', '6', '1', '9', '.', '+', '5', '4', '8', '='}
# ********************
# INPUT :  540+507=
# ATTEMPT:  0
# TARGET :  1047
# PRED :  13..
# POS: {'4', '7', '1', '0'} and {'7', '1', '.', '+', '5', '3', '4', '0', '='}
# ATTEMPT:  1
# TARGET :  1047
# PRED :  85..
# ATTEMPT:  2
# TARGET :  1047
# PRED :  5...
# ATTEMPT:  3
# TARGET :  1047
# PRED :  114.
# POS: {'4', '7', '1', '0'} and {'7', '1', '.', '+', '5', '4', '0', '='}
# ********************
# INPUT :  369+823=
# ATTEMPT:  0
# TARGET :  1192
# PRED :  15..
# POS: {'2', '9', '1'} and {'6', '9', '1', '.', '+', '5', '3', '8', '2', '='}
# ATTEMPT:  1
# TARGET :  1192
# PRED :  933.
# ATTEMPT:  2
# TARGET :  1192
# PRED :  543.
# ATTEMPT:  3
# TARGET :  1192
# PRED :  65..
# ********************
# INPUT :  264+378=
# ATTEMPT:  0
# TARGET :  642.
# PRED :  562.
# POS: {'4', '6', '2', '.'} and {'6', '7', '.', '+', '5', '3', '4', '8', '2', '='}
# ATTEMPT:  1
# TARGET :  642.
# PRED :  134.
# POS: {'4', '6', '2', '.'} and {'6', '7', '1', '.', '+', '3', '4', '8', '2', '='}
# ATTEMPT:  2
# TARGET :  642.
# PRED :  9...
# POS: {'4', '6', '2', '.'} and {'6', '7', '9', '.', '+', '3', '4', '8', '2', '='}
# ATTEMPT:  3
# TARGET :  642.
# PRED :  11..
# POS: {'4', '6', '2', '.'} and {'6', '7', '1', '.', '+', '3', '4', '8', '2', '='}
# ********************
# INPUT :  699+135=
# ATTEMPT:  0
# TARGET :  834.
# PRED :  9...
# ATTEMPT:  1
# TARGET :  834.
# PRED :  7...
# ATTEMPT:  2
# TARGET :  834.
# PRED :  8...
# ATTEMPT:  3
# TARGET :  834.
# PRED :  2...
# ********************
# INPUT :  689+896=
# ATTEMPT:  0
# TARGET :  1585
# PRED :  1...
# ATTEMPT:  1
# TARGET :  1585
# PRED :  7...
# ATTEMPT:  2
# TARGET :  1585
# PRED :  82..
# ATTEMPT:  3
# TARGET :  1585
# PRED :  5...
# ********************
# INPUT :  960+263=
# ATTEMPT:  0
# TARGET :  1223
# PRED :  14..
# POS: {'2', '1', '3'} and {'6', '9', '1', '.', '+', '3', '4', '0', '2', '='}
# ATTEMPT:  1
# TARGET :  1223
# PRED :  4...
# ATTEMPT:  2
# TARGET :  1223
# PRED :  12..
# POS: {'2', '1', '3'} and {'6', '9', '1', '.', '+', '3', '0', '2', '='}
# ATTEMPT:  3
# TARGET :  1223
# PRED :  95..
# ********************
# INPUT :  946+149=
# ATTEMPT:  0
# TARGET :  1095
# PRED :  135.
# ATTEMPT:  1
# TARGET :  1095
# PRED :  5...
# ATTEMPT:  2
# TARGET :  1095
# PRED :  649.
# ATTEMPT:  3
# TARGET :  1095
# PRED :  105.
# POS: {'5', '9', '1', '0'} and {'6', '1', '9', '.', '+', '5', '4', '0', '='}
# ********************
# INPUT :  926+666=
# ATTEMPT:  0
# TARGET :  1592
# PRED :  605.
# ATTEMPT:  1
# TARGET :  1592
# PRED :  15..
# POS: {'2', '9', '1', '5'} and {'6', '9', '1', '.', '+', '5', '2', '='}
# ATTEMPT:  2
# TARGET :  1592
# PRED :  9...
# ATTEMPT:  3
# TARGET :  1592
# PRED :  17..
# ********************
# INPUT :  642+624=
# ATTEMPT:  0
# TARGET :  1266
# PRED :  11..
# POS: {'6', '2', '1'} and {'6', '1', '.', '+', '4', '2', '='}
# ATTEMPT:  1
# TARGET :  1266
# PRED :  845.
# ATTEMPT:  2
# TARGET :  1266
# PRED :  9...
# ATTEMPT:  3
# TARGET :  1266
# PRED :  148.
# POS: {'6', '2', '1'} and {'6', '1', '.', '+', '4', '8', '2', '='}
# ********************
# INPUT :  568+308=
# ATTEMPT:  0
# TARGET :  876.
# PRED :  12..
# ATTEMPT:  1
# TARGET :  876.
# PRED :  108.
# ATTEMPT:  2
# TARGET :  876.
# PRED :  11..
# ATTEMPT:  3
# TARGET :  876.
# PRED :  11..
# ********************
# INPUT :  783+836=
# ATTEMPT:  0
# TARGET :  1619
# PRED :  43..
# ATTEMPT:  1
# TARGET :  1619
# PRED :  103.
# ATTEMPT:  2
# TARGET :  1619
# PRED :  55..
# ATTEMPT:  3
# TARGET :  1619
# PRED :  6...
# ********************
# INPUT :  215+546=
# ATTEMPT:  0
# TARGET :  761.
# PRED :  8...
# ATTEMPT:  1
# TARGET :  761.
# PRED :  15..
# ATTEMPT:  2
# TARGET :  761.
# PRED :  179.
# POS: {'6', '7', '1', '.'} and {'6', '7', '1', '9', '.', '+', '5', '4', '2', '='}
# ATTEMPT:  3
# TARGET :  761.
# PRED :  9...
# ********************
# INPUT :  127+544=
# ATTEMPT:  0
# TARGET :  671.
# PRED :  98..
# ATTEMPT:  1
# TARGET :  671.
# PRED :  11..
# ATTEMPT:  2
# TARGET :  671.
# PRED :  8...
# ATTEMPT:  3
# TARGET :  671.
# PRED :  8...
# ********************
# INPUT :  254+310=
# ATTEMPT:  0
# TARGET :  564.
# PRED :  14..
# ATTEMPT:  1
# TARGET :  564.
# PRED :  15..
# ATTEMPT:  2
# TARGET :  564.
# PRED :  160.
# POS: {'4', '6', '5', '.'} and {'6', '1', '.', '+', '5', '3', '4', '0', '2', '='}
# ATTEMPT:  3
# TARGET :  564.
# PRED :  14..
# ********************
# INPUT :  250+133=
# ATTEMPT:  0
# TARGET :  383.
# PRED :  75..
# ATTEMPT:  1
# TARGET :  383.
# PRED :  4...
# ATTEMPT:  2
# TARGET :  383.
# PRED :  13..
# ATTEMPT:  3
# TARGET :  383.
# PRED :  9...
# ********************
# INPUT :  742+778=
# ATTEMPT:  0
# TARGET :  1520
# PRED :  10..
# ATTEMPT:  1
# TARGET :  1520
# PRED :  6...
# ATTEMPT:  2
# TARGET :  1520
# PRED :  3...
# ATTEMPT:  3
# TARGET :  1520
# PRED :  121.
# ********************
# INPUT :  566+586=
# ATTEMPT:  0
# TARGET :  1152
# PRED :  105.
# ATTEMPT:  1
# TARGET :  1152
# PRED :  3...
# ATTEMPT:  2
# TARGET :  1152
# PRED :  92..
# ATTEMPT:  3
# TARGET :  1152
# PRED :  15..
# ********************
# INPUT :  203+172=
# ATTEMPT:  0
# TARGET :  375.
# PRED :  9...
# ATTEMPT:  1
# TARGET :  375.
# PRED :  10..
# ATTEMPT:  2
# TARGET :  375.
# PRED :  6...
# ATTEMPT:  3
# TARGET :  375.
# PRED :  18..
# ********************
# INPUT :  365+200=
# ATTEMPT:  0
# TARGET :  565.
# PRED :  10..
# POS: {'6', '5', '.'} and {'6', '1', '.', '+', '5', '3', '0', '2', '='}
# ATTEMPT:  1
# TARGET :  565.
# PRED :  3...
# POS: {'6', '5', '.'} and {'6', '.', '+', '5', '3', '0', '2', '='}
# ATTEMPT:  2
# TARGET :  565.
# PRED :  18..
# POS: {'6', '5', '.'} and {'6', '1', '.', '+', '5', '3', '0', '8', '2', '='}
# ATTEMPT:  3
# TARGET :  565.
# PRED :  10..
# POS: {'6', '5', '.'} and {'6', '1', '.', '+', '5', '3', '0', '2', '='}
# ********************
# INPUT :  194+499=
# ATTEMPT:  0
# TARGET :  693.
# PRED :  4...
# ATTEMPT:  1
# TARGET :  693.
# PRED :  4...
# ATTEMPT:  2
# TARGET :  693.
# PRED :  13..
# ATTEMPT:  3
# TARGET :  693.
# PRED :  170.
# ********************
# INPUT :  325+175=
# ATTEMPT:  0
# TARGET :  500.
# PRED :  88..
# ATTEMPT:  1
# TARGET :  500.
# PRED :  99..
# ATTEMPT:  2
# TARGET :  500.
# PRED :  72..
# ATTEMPT:  3
# TARGET :  500.
# PRED :  5...
# ********************
# INPUT :  141+985=
# ATTEMPT:  0
# TARGET :  1126
# PRED :  16..
# ATTEMPT:  1
# TARGET :  1126
# PRED :  11..
# ATTEMPT:  2
# TARGET :  1126
# PRED :  7...
# ATTEMPT:  3
# TARGET :  1126
# PRED :  8...
# ********************
# INPUT :  223+442=
# ATTEMPT:  0
# TARGET :  665.
# PRED :  8...
# ATTEMPT:  1
# TARGET :  665.
# PRED :  81..
# ATTEMPT:  2
# TARGET :  665.
# PRED :  56..
# POS: {'6', '5', '.'} and {'6', '.', '+', '5', '3', '4', '2', '='}
# ATTEMPT:  3
# TARGET :  665.
# PRED :  10..
# ********************
# INPUT :  554+332=
# ATTEMPT:  0
# TARGET :  886.
# PRED :  88..
# ATTEMPT:  1
# TARGET :  886.
# PRED :  12..
# ATTEMPT:  2
# TARGET :  886.
# PRED :  10..
# ATTEMPT:  3
# TARGET :  886.
# PRED :  119.
# ********************
# INPUT :  459+423=
# ATTEMPT:  0
# TARGET :  882.
# PRED :  117.
# ATTEMPT:  1
# TARGET :  882.
# PRED :  10..
# ATTEMPT:  2
# TARGET :  882.
# PRED :  12..
# ATTEMPT:  3
# TARGET :  882.
# PRED :  161.
# ********************
# INPUT :  338+343=
# ATTEMPT:  0
# TARGET :  681.
# PRED :  98..
# ATTEMPT:  1
# TARGET :  681.
# PRED :  6...
# ATTEMPT:  2
# TARGET :  681.
# PRED :  457.
# ATTEMPT:  3
# TARGET :  681.
# PRED :  7...
# ********************
# INPUT :  608+539=
# ATTEMPT:  0
# TARGET :  1147
# PRED :  7...
# ATTEMPT:  1
# TARGET :  1147
# PRED :  101.
# ATTEMPT:  2
# TARGET :  1147
# PRED :  113.
# ATTEMPT:  3
# TARGET :  1147
# PRED :  850.
# ********************
# INPUT :  723+895=
# ATTEMPT:  0
# TARGET :  1618
# PRED :  9...
# ATTEMPT:  1
# TARGET :  1618
# PRED :  9...
# ATTEMPT:  2
# TARGET :  1618
# PRED :  97..
# ATTEMPT:  3
# TARGET :  1618
# PRED :  79..
# ********************
# INPUT :  131+706=
# ATTEMPT:  0
# TARGET :  837.
# PRED :  58..
# POS: {'7', '.', '3', '8'} and {'7', '6', '1', '.', '+', '5', '3', '0', '8', '='}
# ATTEMPT:  1
# TARGET :  837.
# PRED :  12..
# ATTEMPT:  2
# TARGET :  837.
# PRED :  4...
# ATTEMPT:  3
# TARGET :  837.
# PRED :  12..
# ********************
# INPUT :  512+820=
# ATTEMPT:  0
# TARGET :  1332
# PRED :  16..
# ATTEMPT:  1
# TARGET :  1332
# PRED :  124.
# ATTEMPT:  2
# TARGET :  1332
# PRED :  14..
# ATTEMPT:  3
# TARGET :  1332
# PRED :  7...
# ********************
# INPUT :  496+496=
# ATTEMPT:  0
# TARGET :  992.
# PRED :  9...
# ATTEMPT:  1
# TARGET :  992.
# PRED :  122.
# POS: {'2', '9', '.'} and {'6', '9', '1', '.', '+', '4', '2', '='}
# ATTEMPT:  2
# TARGET :  992.
# PRED :  8...
# ATTEMPT:  3
# TARGET :  992.
# PRED :  10..
# ********************
# INPUT :  759+411=
# ATTEMPT:  0
# TARGET :  1170
# PRED :  95..
# ATTEMPT:  1
# TARGET :  1170
# PRED :  19..
# ATTEMPT:  2
# TARGET :  1170
# PRED :  7...
# ATTEMPT:  3
# TARGET :  1170
# PRED :  10..
# POS: {'7', '1', '0'} and {'7', '9', '1', '.', '+', '5', '4', '0', '='}
# ********************
# INPUT :  781+172=
# ATTEMPT:  0
# TARGET :  953.
# PRED :  10..
# ATTEMPT:  1
# TARGET :  953.
# PRED :  7...
# ATTEMPT:  2
# TARGET :  953.
# PRED :  1...
# ATTEMPT:  3
# TARGET :  953.
# PRED :  106.
# ********************
# INPUT :  488+257=
# ATTEMPT:  0
# TARGET :  745.
# PRED :  8...
# ...
# INPUT :  458+193=
# ATTEMPT:  0
# TARGET :  651.
# PRED :  10..
# ATTEMPT:  1
# TARGET :  651.
# PRED :  12..
# ATTEMPT:  2
# TARGET :  651.
# PRED :  133.
# ATTEMPT:  3
# TARGET :  651.
# PRED :  74..
# ********************
# INPUT :  369+256=
# ATTEMPT:  0
# TARGET :  625.
# PRED :  12..
# POS: {'6', '2', '5', '.'} and {'6', '9', '1', '.', '+', '5', '3', '2', '='}
# ATTEMPT:  1
# TARGET :  625.
# PRED :  4...
# POS: {'6', '2', '5', '.'} and {'6', '9', '.', '+', '5', '3', '4', '2', '='}
# ATTEMPT:  2
# TARGET :  625.
# PRED :  10..
# POS: {'6', '2', '5', '.'} and {'6', '9', '1', '.', '+', '5', '3', '0', '2', '='}
# ATTEMPT:  3
# TARGET :  625.
# PRED :  118.
# POS: {'6', '2', '5', '.'} and {'6', '9', '1', '.', '+', '5', '3', '8', '2', '='}
# ********************
# INPUT :  159+330=
# ATTEMPT:  0
# TARGET :  489.
# PRED :  103.
# ATTEMPT:  1
# TARGET :  489.
# PRED :  6...
# ATTEMPT:  2
# TARGET :  489.
# PRED :  14..
# ATTEMPT:  3
# TARGET :  489.
# PRED :  6...
# ********************
# INPUT :  506+767=
# ATTEMPT:  0
# TARGET :  1273
# PRED :  11..
# ATTEMPT:  1
# TARGET :  1273
# PRED :  14..
# ATTEMPT:  2
# TARGET :  1273
# PRED :  710.
# ATTEMPT:  3
# TARGET :  1273
# PRED :  106.
# ********************
# INPUT :  773+986=
# ATTEMPT:  0
# TARGET :  1759
# PRED :  7...
# ATTEMPT:  1
# TARGET :  1759
# PRED :  835.
# ATTEMPT:  2
# TARGET :  1759
# PRED :  15..
# POS: {'7', '9', '1', '5'} and {'7', '6', '9', '1', '.', '+', '5', '3', '8', '='}
# ATTEMPT:  3
# TARGET :  1759
# PRED :  764.
# ********************
# INPUT :  133+483=
# ATTEMPT:  0
# TARGET :  616.
# PRED :  351.
# ATTEMPT:  1
# TARGET :  616.
# PRED :  108.
# ATTEMPT:  2
# TARGET :  616.
# PRED :  8...
# ATTEMPT:  3
# TARGET :  616.
# PRED :  14..
# ********************
# INPUT :  253+340=
# ATTEMPT:  0
# TARGET :  593.
# PRED :  0...
# ATTEMPT:  1
# TARGET :  593.
# PRED :  7...
# ATTEMPT:  2
# TARGET :  593.
# PRED :  9...
# POS: {'.', '9', '5', '3'} and {'9', '.', '+', '5', '3', '4', '0', '2', '='}
# ATTEMPT:  3
# TARGET :  593.
# PRED :  15..
# ********************
# INPUT :  999+360=
# ATTEMPT:  0
# TARGET :  1359
# PRED :  112.
# ATTEMPT:  1
# TARGET :  1359
# PRED :  9...
# ATTEMPT:  2
# TARGET :  1359
# PRED :  4...
# ATTEMPT:  3
# TARGET :  1359
# PRED :  16..
# ********************
# INPUT :  733+636=
# ATTEMPT:  0
# TARGET :  1369
# PRED :  10..
# ATTEMPT:  1
# TARGET :  1369
# PRED :  1...
# ATTEMPT:  2
# TARGET :  1369
# PRED :  5...
# ATTEMPT:  3
# TARGET :  1369
# PRED :  88..
# ********************
# INPUT :  935+279=
# ATTEMPT:  0
# TARGET :  1214
# PRED :  3...
# ATTEMPT:  1
# TARGET :  1214
# PRED :  12..
# ATTEMPT:  2
# TARGET :  1214
# PRED :  10..
# ATTEMPT:  3
# TARGET :  1214
# PRED :  12..
# ********************
# INPUT :  499+741=
# ATTEMPT:  0
# TARGET :  1240
# PRED :  111.
# ATTEMPT:  1
# TARGET :  1240
# PRED :  40..
# ATTEMPT:  2
# TARGET :  1240
# PRED :  8...
# ATTEMPT:  3
# TARGET :  1240
# PRED :  158.
# ********************
# INPUT :  260+185=
# ATTEMPT:  0
# TARGET :  445.
# PRED :  7...
# ATTEMPT:  1
# TARGET :  445.
# PRED :  820.
# ATTEMPT:  2
# TARGET :  445.
# PRED :  11..
# ATTEMPT:  3
# TARGET :  445.
# PRED :  79..
# ********************
# INPUT :  121+490=
# ATTEMPT:  0
# TARGET :  611.
# PRED :  11..
# ATTEMPT:  1
# TARGET :  611.
# PRED :  6...
# POS: {'6', '1', '.'} and {'6', '9', '1', '.', '+', '4', '0', '2', '='}
# ATTEMPT:  2
# TARGET :  611.
# PRED :  15..
# ATTEMPT:  3
# TARGET :  611.
# PRED :  18..
# ********************
# INPUT :  81.+597=
# ATTEMPT:  0
# TARGET :  678.
# PRED :  112.
# ATTEMPT:  1
# TARGET :  678.
# PRED :  9...
# ATTEMPT:  2
# TARGET :  678.
# PRED :  7...
# ATTEMPT:  3
# TARGET :  678.
# PRED :  606.
# POS: {'7', '6', '.', '8'} and {'7', '6', '1', '9', '.', '+', '5', '0', '8', '='}
# ********************
# INPUT :  493+795=
# ATTEMPT:  0
# TARGET :  1288
# PRED :  76..
# ATTEMPT:  1
# TARGET :  1288
# PRED :  6...
# ATTEMPT:  2
# TARGET :  1288
# PRED :  7...
# ATTEMPT:  3
# TARGET :  1288
# PRED :  855.
# ********************
# INPUT :  706+808=
# ATTEMPT:  0
# TARGET :  1514
# PRED :  12..
# ATTEMPT:  1
# TARGET :  1514
# PRED :  50..
# ATTEMPT:  2
# TARGET :  1514
# PRED :  172.
# ATTEMPT:  3
# TARGET :  1514
# PRED :  538.
# ********************
# INPUT :  704+167=
# ATTEMPT:  0
# TARGET :  871.
# PRED :  11..
# ATTEMPT:  1
# TARGET :  871.
# PRED :  11..
# ATTEMPT:  2
# TARGET :  871.
# PRED :  5...
# ATTEMPT:  3
# TARGET :  871.
# PRED :  83..
# POS: {'7', '.', '1', '8'} and {'7', '6', '1', '.', '+', '3', '4', '0', '8', '='}
# ********************
# INPUT :  812+957=
# ATTEMPT:  0
# TARGET :  1769
# PRED :  9...
# ATTEMPT:  1
# TARGET :  1769
# PRED :  3...
# ATTEMPT:  2
# TARGET :  1769
# PRED :  94..
# ATTEMPT:  3
# TARGET :  1769
# PRED :  77..
# ********************
# INPUT :  856+327=
# ATTEMPT:  0
# TARGET :  1183
# PRED :  454.
# ATTEMPT:  1
# TARGET :  1183
# PRED :  7...
# ATTEMPT:  2
# TARGET :  1183
# PRED :  864.
# ATTEMPT:  3
# TARGET :  1183
# PRED :  6...
# ********************
# INPUT :  653+167=
# ATTEMPT:  0
# TARGET :  820.
# PRED :  14..
# ATTEMPT:  1
# TARGET :  820.
# PRED :  5...
# ATTEMPT:  2
# TARGET :  820.
# PRED :  10..
# ATTEMPT:  3
# TARGET :  820.
# PRED :  5...
# ********************
# INPUT :  381+874=
# ATTEMPT:  0
# TARGET :  1255
# PRED :  124.
# ATTEMPT:  1
# TARGET :  1255
# PRED :  7...
# ATTEMPT:  2
# TARGET :  1255
# PRED :  7...
# ATTEMPT:  3
# TARGET :  1255
# PRED :  112.
# ********************
# INPUT :  392+100=
# ATTEMPT:  0
# TARGET :  492.
# PRED :  146.
# POS: {'4', '2', '9', '.'} and {'6', '9', '1', '.', '+', '3', '4', '0', '2', '='}
# ATTEMPT:  1
# TARGET :  492.
# PRED :  822.
# ATTEMPT:  2
# TARGET :  492.
# PRED :  4...
# POS: {'4', '2', '9', '.'} and {'9', '1', '.', '+', '3', '4', '0', '2', '='}
# ATTEMPT:  3
# TARGET :  492.
# PRED :  12..
# ********************
# INPUT :  506+387=
# ATTEMPT:  0
# TARGET :  893.
# PRED :  3...
# ATTEMPT:  1
# TARGET :  893.
# PRED :  13..
# ATTEMPT:  2
# TARGET :  893.
# PRED :  848.
# ATTEMPT:  3
# TARGET :  893.
# PRED :  10..
# ********************
# INPUT :  319+743=
# ATTEMPT:  0
# TARGET :  1062
# PRED :  5...
# ATTEMPT:  1
# TARGET :  1062
# PRED :  105.
# ATTEMPT:  2
# TARGET :  1062
# PRED :  92..
# ATTEMPT:  3
# TARGET :  1062
# PRED :  672.
# ********************
# INPUT :  336+34.=
# ATTEMPT:  0
# TARGET :  370.
# PRED :  5...
# ATTEMPT:  1
# TARGET :  370.
# PRED :  17..
# ATTEMPT:  2
# TARGET :  370.
# PRED :  7...
# ATTEMPT:  3
# TARGET :  370.
# PRED :  942.
# ********************
# INPUT :  238+648=
# ATTEMPT:  0
# TARGET :  886.
# PRED :  7...
# POS: {'6', '.', '8'} and {'6', '7', '.', '+', '3', '4', '8', '2', '='}
# ATTEMPT:  1
# TARGET :  886.
# PRED :  4...
# POS: {'6', '.', '8'} and {'6', '.', '+', '3', '4', '8', '2', '='}
# ATTEMPT:  2
# TARGET :  886.
# PRED :  15..
# POS: {'6', '.', '8'} and {'6', '1', '.', '+', '5', '3', '4', '8', '2', '='}
# ATTEMPT:  3
# TARGET :  886.
# PRED :  9...
# POS: {'6', '.', '8'} and {'6', '9', '.', '+', '3', '4', '8', '2', '='}
# ********************
# INPUT :  883+97.=
# ATTEMPT:  0
# TARGET :  980.
# PRED :  11..
# ATTEMPT:  1
# TARGET :  980.
# PRED :  13..
# ATTEMPT:  2
# TARGET :  980.
# PRED :  6...
# ATTEMPT:  3
# TARGET :  980.
# PRED :  2...
# ********************
# INPUT :  713+942=
# ATTEMPT:  0
# TARGET :  1655
# PRED :  4...
# ATTEMPT:  1
# TARGET :  1655
# PRED :  1...
# ATTEMPT:  2
# TARGET :  1655
# PRED :  15..
# ATTEMPT:  3
# TARGET :  1655
# PRED :  8...
# ********************
# INPUT :  888+958=
# ATTEMPT:  0
# TARGET :  1846
# PRED :  7...
# ATTEMPT:  1
# TARGET :  1846
# PRED :  4...
# ATTEMPT:  2
# TARGET :  1846
# PRED :  12..
# ATTEMPT:  3
# TARGET :  1846
# PRED :  14..
# ********************
# INPUT :  347+686=
# ATTEMPT:  0
# TARGET :  1033
# PRED :  3...
# ATTEMPT:  1
# TARGET :  1033
# PRED :  12..
# ATTEMPT:  2
# TARGET :  1033
# PRED :  10..
# POS: {'1', '0', '3'} and {'6', '7', '1', '.', '+', '3', '4', '0', '8', '='}
# ATTEMPT:  3
# TARGET :  1033
# PRED :  10..
# POS: {'1', '0', '3'} and {'6', '7', '1', '.', '+', '3', '4', '0', '8', '='}
# ********************
# INPUT :  894+837=
# ATTEMPT:  0
# TARGET :  1731
# PRED :  16..
# POS: {'7', '1', '3'} and {'7', '6', '9', '1', '.', '+', '3', '4', '8', '='}
# ATTEMPT:  1
# TARGET :  1731
# PRED :  105.
# POS: {'7', '1', '3'} and {'7', '9', '1', '.', '+', '5', '3', '4', '0', '8', '='}
# ATTEMPT:  2
# TARGET :  1731
# PRED :  4...
# ATTEMPT:  3
# TARGET :  1731
# PRED :  955.
# ********************
# INPUT :  323+170=
# ATTEMPT:  0
# TARGET :  493.
# PRED :  97..
# ATTEMPT:  1
# TARGET :  493.
# PRED :  6...
# ATTEMPT:  2
# TARGET :  493.
# PRED :  686.
# ATTEMPT:  3
# TARGET :  493.
# PRED :  106.
# ********************
# INPUT :  315+310=
# ATTEMPT:  0
# TARGET :  625.
# PRED :  6...
# ATTEMPT:  1
# TARGET :  625.
# PRED :  104.
# ATTEMPT:  2
# TARGET :  625.
# PRED :  4...
# ATTEMPT:  3
# TARGET :  625.
# PRED :  78..
# ********************
# INPUT :  760+132=
# ATTEMPT:  0
# TARGET :  892.
# PRED :  15..
# ATTEMPT:  1
# TARGET :  892.
# PRED :  4...
# ATTEMPT:  2
# TARGET :  892.
# PRED :  8...
# ATTEMPT:  3
# TARGET :  892.
# PRED :  110.
# ********************
# INPUT :  751+363=
# ATTEMPT:  0
# TARGET :  1114
# PRED :  10..
# ATTEMPT:  1
# TARGET :  1114
# PRED :  88..
# ATTEMPT:  2
# TARGET :  1114
# PRED :  11..
# ATTEMPT:  3
# TARGET :  1114
# PRED :  115.
# ********************
# INPUT :  915+847=
# ATTEMPT:  0
# TARGET :  1762
# PRED :  91..
# ATTEMPT:  1
# TARGET :  1762
# PRED :  658.
# ATTEMPT:  2
# TARGET :  1762
# PRED :  869.
# ATTEMPT:  3
# TARGET :  1762
# PRED :  6...
# ********************
# INPUT :  707+333=
# ATTEMPT:  0
# TARGET :  1040
# PRED :  69..
# ATTEMPT:  1
# TARGET :  1040
# PRED :  122.
# ATTEMPT:  2
# TARGET :  1040
# PRED :  9...
# ATTEMPT:  3
# TARGET :  1040
# PRED :  17..
# ********************
# INPUT :  58.+264=
# ATTEMPT:  0
# TARGET :  322.
# PRED :  14..
# ATTEMPT:  1
# TARGET :  322.
# PRED :  6...
# ATTEMPT:  2
# TARGET :  322.
# PRED :  18..
# ATTEMPT:  3
# TARGET :  322.
# PRED :  825.
# ********************
# INPUT :  466+44.=
# ATTEMPT:  0
# TARGET :  510.
# PRED :  7...
# ATTEMPT:  1
# TARGET :  510.
# PRED :  5...
# ATTEMPT:  2
# TARGET :  510.
# PRED :  131.
# ATTEMPT:  3
# TARGET :  510.
# PRED :  15..
# ********************
# INPUT :  687+130=
# ATTEMPT:  0
# TARGET :  817.
# PRED :  6...
# POS: {'7', '.', '1', '8'} and {'7', '6', '1', '.', '+', '3', '0', '8', '='}
# ATTEMPT:  1
# TARGET :  817.
# PRED :  121.
# POS: {'7', '.', '1', '8'} and {'7', '6', '1', '.', '+', '3', '0', '8', '2', '='}
# ATTEMPT:  2
# TARGET :  817.
# PRED :  2...
# POS: {'7', '.', '1', '8'} and {'7', '6', '1', '.', '+', '3', '0', '8', '2', '='}
# ATTEMPT:  3
# TARGET :  817.
# PRED :  8...
# POS: {'7', '.', '1', '8'} and {'7', '6', '1', '.', '+', '3', '0', '8', '='}
# ********************
# INPUT :  945+533=
# ATTEMPT:  0
# TARGET :  1478
# PRED :  15..
# ATTEMPT:  1
# TARGET :  1478
# PRED :  9...
# ATTEMPT:  2
# TARGET :  1478
# PRED :  9...
# ATTEMPT:  3
# TARGET :  1478
# PRED :  2...
# ********************
# INPUT :  172+517=
# ATTEMPT:  0
# TARGET :  689.
# PRED :  124.
# ATTEMPT:  1
# TARGET :  689.
# PRED :  12..
# ATTEMPT:  2
# TARGET :  689.
# PRED :  71..
# ATTEMPT:  3
# TARGET :  689.
# PRED :  15..
# ********************
# INPUT :  700+781=
# ATTEMPT:  0
# TARGET :  1481
# PRED :  13..
# ATTEMPT:  1
# TARGET :  1481
# PRED :  148.
# POS: {'4', '1', '8'} and {'7', '1', '.', '+', '4', '0', '8', '='}
# ATTEMPT:  2
# TARGET :  1481
# PRED :  7...
# ATTEMPT:  3
# TARGET :  1481
# PRED :  6...
# ********************
# INPUT :  814+220=
# ATTEMPT:  0
# TARGET :  1034
# PRED :  10..
# ATTEMPT:  1
# TARGET :  1034
# PRED :  138.
# POS: {'4', '1', '0', '3'} and {'1', '.', '+', '3', '4', '0', '8', '2', '='}
# ATTEMPT:  2
# TARGET :  1034
# PRED :  9...
# ATTEMPT:  3
# TARGET :  1034
# PRED :  6...
# ********************
# INPUT :  932+641=
# ATTEMPT:  0
# TARGET :  1573
# PRED :  815.
# ATTEMPT:  1
# TARGET :  1573
# PRED :  13..
# ATTEMPT:  2
# TARGET :  1573
# PRED :  5...
# ATTEMPT:  3
# TARGET :  1573
# PRED :  764.
# ********************
# INPUT :  512+265=
# ATTEMPT:  0
# TARGET :  777.
# PRED :  71..
# POS: {'7', '.'} and {'6', '7', '1', '.', '+', '5', '2', '='}
# ATTEMPT:  1
# TARGET :  777.
# PRED :  9...
# ATTEMPT:  2
# TARGET :  777.
# PRED :  0...
# ATTEMPT:  3
# TARGET :  777.
# PRED :  4...
# ********************
# INPUT :  715+672=
# ATTEMPT:  0
# TARGET :  1387
# PRED :  16..
# ATTEMPT:  1
# TARGET :  1387
# PRED :  6...
# ATTEMPT:  2
# TARGET :  1387
# PRED :  650.
# ATTEMPT:  3
# TARGET :  1387
# PRED :  7...
# ********************
# INPUT :  672+579=
# ATTEMPT:  0
# TARGET :  1251
# PRED :  91..
# POS: {'2', '1', '5'} and {'7', '6', '9', '1', '.', '+', '5', '2', '='}
# ATTEMPT:  1
# TARGET :  1251
# PRED :  100.
# POS: {'2', '1', '5'} and {'7', '6', '9', '1', '.', '+', '5', '0', '2', '='}
# ATTEMPT:  2
# TARGET :  1251
# PRED :  48..
# ATTEMPT:  3
# TARGET :  1251
# PRED :  155.
# POS: {'2', '1', '5'} and {'7', '6', '9', '1', '.', '+', '5', '2', '='}
# ********************
# INPUT :  455+394=
# ATTEMPT:  0
# TARGET :  849.
# PRED :  11..
# ATTEMPT:  1
# TARGET :  849.
# PRED :  16..
# ATTEMPT:  2
# TARGET :  849.
# PRED :  11..
# ATTEMPT:  3
# TARGET :  849.
# PRED :  14..
# ********************
# INPUT :  948+372=
# ATTEMPT:  0
# TARGET :  1320
# PRED :  10..
# POS: {'2', '1', '0', '3'} and {'7', '9', '1', '.', '+', '3', '4', '0', '8', '2', '='}
# ATTEMPT:  1
# TARGET :  1320
# PRED :  4...
# ATTEMPT:  2
# TARGET :  1320
# PRED :  127.
# ATTEMPT:  3
# TARGET :  1320
# PRED :  4...
# ********************
# INPUT :  531+490=
# ATTEMPT:  0
# TARGET :  1021
# PRED :  18..
# ATTEMPT:  1
# TARGET :  1021
# PRED :  4...
# ATTEMPT:  2
# TARGET :  1021
# PRED :  6...
# ATTEMPT:  3
# TARGET :  1021
# PRED :  16..
# ********************
# INPUT :  942+812=
# ATTEMPT:  0
# TARGET :  1754
# PRED :  12..
# ATTEMPT:  1
# TARGET :  1754
# PRED :  18..
# ATTEMPT:  2
# TARGET :  1754
# PRED :  16..
# ATTEMPT:  3
# TARGET :  1754
# PRED :  720.
# ********************
# INPUT :  701+599=
# ATTEMPT:  0
# TARGET :  1300
# PRED :  113.
# POS: {'1', '0', '3'} and {'7', '1', '9', '.', '+', '5', '3', '0', '='}
# ATTEMPT:  1
# TARGET :  1300
# PRED :  110.
# ATTEMPT:  2
# TARGET :  1300
# PRED :  11..
# ATTEMPT:  3
# TARGET :  1300
# PRED :  9...
# ********************
# INPUT :  303+777=
# ATTEMPT:  0
# TARGET :  1080
# PRED :  129.
# ATTEMPT:  1
# TARGET :  1080
# PRED :  142.
# ATTEMPT:  2
# TARGET :  1080
# PRED :  8...
# ATTEMPT:  3
# TARGET :  1080
# PRED :  9...
# ********************
# INPUT :  43.+811=
# ATTEMPT:  0
# TARGET :  854.
# PRED :  15..
# POS: {'4', '.', '5', '8'} and {'1', '.', '+', '5', '3', '4', '8', '='}
# ATTEMPT:  1
# TARGET :  854.
# PRED :  14..
# ATTEMPT:  2
# TARGET :  854.
# PRED :  9...
# ATTEMPT:  3
# TARGET :  854.
# PRED :  87..
# ********************
# INPUT :  835+994=
# ATTEMPT:  0
# TARGET :  1829
# PRED :  13..
# ATTEMPT:  1
# TARGET :  1829
# PRED :  1...
# ATTEMPT:  2
# TARGET :  1829
# PRED :  10..
# ATTEMPT:  3
# TARGET :  1829
# PRED :  478.
# ********************
# INPUT :  94.+387=
# ATTEMPT:  0
# TARGET :  481.
# PRED :  10..
# POS: {'4', '.', '1', '8'} and {'7', '9', '1', '.', '+', '3', '4', '0', '8', '='}
# ATTEMPT:  1
# TARGET :  481.
# PRED :  135.
# POS: {'4', '.', '1', '8'} and {'7', '9', '1', '.', '+', '5', '3', '4', '8', '='}
# ATTEMPT:  2
# TARGET :  481.
# PRED :  16..
# POS: {'4', '.', '1', '8'} and {'7', '6', '9', '1', '.', '+', '3', '4', '8', '='}
# ATTEMPT:  3
# TARGET :  481.
# PRED :  179.
# POS: {'4', '.', '1', '8'} and {'7', '9', '1', '.', '+', '3', '4', '8', '='}
# ********************
# INPUT :  451+641=
# ATTEMPT:  0
# TARGET :  1092
# PRED :  5...
# ATTEMPT:  1
# TARGET :  1092
# PRED :  175.
# ATTEMPT:  2
# TARGET :  1092
# PRED :  415.
# ATTEMPT:  3
# TARGET :  1092
# PRED :  19..
# ********************
# INPUT :  307+720=
# ATTEMPT:  0
# TARGET :  1027
# PRED :  9...
# ATTEMPT:  1
# TARGET :  1027
# PRED :  10..
# POS: {'7', '2', '1', '0'} and {'7', '1', '.', '+', '3', '0', '2', '='}
# ATTEMPT:  2
# TARGET :  1027
# PRED :  165.
# POS: {'7', '2', '1', '0'} and {'7', '6', '1', '.', '+', '5', '3', '0', '2', '='}
# ATTEMPT:  3
# TARGET :  1027
# PRED :  6...
# ********************
# INPUT :  273+781=
# ATTEMPT:  0
# TARGET :  1054
# PRED :  16..
# ATTEMPT:  1
# TARGET :  1054
# PRED :  174.
# ATTEMPT:  2
# TARGET :  1054
# PRED :  601.
# ATTEMPT:  3
# TARGET :  1054
# PRED :  112.
# ********************
# INPUT :  713+853=
# ATTEMPT:  0
# TARGET :  1566
# PRED :  8...
# ATTEMPT:  1
# TARGET :  1566
# PRED :  9...
# ATTEMPT:  2
# TARGET :  1566
# PRED :  11..
# ATTEMPT:  3
# TARGET :  1566
# PRED :  7...
# ********************
# INPUT :  719+288=
# ATTEMPT:  0
# TARGET :  1007
# PRED :  16..
# ATTEMPT:  1
# TARGET :  1007
# PRED :  906.
# POS: {'7', '1', '0'} and {'7', '6', '9', '1', '.', '+', '0', '8', '2', '='}
# ATTEMPT:  2
# TARGET :  1007
# PRED :  0...
# POS: {'7', '1', '0'} and {'7', '9', '1', '.', '+', '0', '8', '2', '='}
# ATTEMPT:  3
# TARGET :  1007
# PRED :  148.
# ********************
# INPUT :  936+49.=
# ATTEMPT:  0
# TARGET :  985.
# PRED :  69..
# ATTEMPT:  1
# TARGET :  985.
# PRED :  16..
# ATTEMPT:  2
# TARGET :  985.
# PRED :  13..
# ATTEMPT:  3
# TARGET :  985.
# PRED :  111.
# ********************
# INPUT :  186+544=
# ATTEMPT:  0
# TARGET :  730.
# PRED :  13..
# ATTEMPT:  1
# TARGET :  730.
# PRED :  68..
# ATTEMPT:  2
# TARGET :  730.
# PRED :  19..
# ATTEMPT:  3
# TARGET :  730.
# PRED :  3...
# ********************
# INPUT :  12.+316=
# ATTEMPT:  0
# TARGET :  328.
# PRED :  16..
# ATTEMPT:  1
# TARGET :  328.
# PRED :  102.
# ATTEMPT:  2
# TARGET :  328.
# PRED :  46..
# ATTEMPT:  3
# TARGET :  328.
# PRED :  7...
# ********************
# Accuracy: 0.37
